# %%
# Import statements.
import numpy as np
import random as rand
import torch
import math
import matplotlib.pyplot as plt
from torch import nn
import torch.nn.functional as F
import torch.distributions as tdist
# %matplotlib inline

# %%
# Generates network weights.
def generate_weights(starting_size, ending_size, weights_needed):
    difference = (starting_size - ending_size) / (weights_needed + 1)
    weights = []
    for i in range(weights_needed):
        weights.append(int(starting_size - (difference * (i+1))))
    return weights

# %%
# Link between two graph nodes.
class LINK:
    
    # Constructor.
    def __init__(self, start, end, reward, actions):
        self.start = start
        self.end = end
        self.reward = reward
        self.actions = actions
        self.distance = 0
        for i in range(len(start.state)):
            self.distance += (start.state[i] - end.state[i]) ** 2
        
    # Returns a copy of the action set.
    def copy_actions(self):
        return [a for a in self.actions]

# Graph Node.
class NODE:
    
    # Constructor.
    def __init__(self, state, discovery_time, op=None):
        self.state = state
        self.discovery_time = discovery_time
        self.forward_links = []
        self.backward_links = []
        self.op = op
        
    # Checks if the provided state is identical this this node.
    def is_same(self, state):
        if self.op is None:
            for i in range(len(self.state)):
                if self.state[i] != state[i]:
                    return False
            return True
        else:
            return self.op(self.state, state)
        
    # Creates a forward link between this node and the provided node.
    def construct_link(self, node, reward, actions):
        for link in self.forward_links:
            # Checks if a link between the nodes already exists.
            if link.end.is_same(node.state):
                # Updates the link to the new score and actions if they are better.
                if reward > link.reward:
                    link.reward = reward
                    link.actions = actions
                    return
        # If the link doesn't exist.
        link = LINK(self, node, reward, actions)
        self.forward_links.append(link)
        node.backward_links.append(link)

# %%
# Policy recommendor network.
class POLICY_NET(nn.Module):
    
    # Constructor.
    def __init__(self, input_size, output_size, layer_count, output_count, t_device):
        super().__init__()
        weights = generate_weights(input_size, output_size, layer_count)
        prev_weight = input_size
        self.t_device = t_device
        self.hidden_layers = []
        for w in weights:
            self.hidden_layers.append(nn.Linear(prev_weight, w).to(self.t_device))
            prev_weight = w
        self.output_layers = []
        for i in range(output_count):
            self.output_layers.append(nn.Linear(prev_weight, output_size).to(self.t_device))
        self.sigmoid = nn.Sigmoid()
        self.relu = F.relu
        self.softmax = nn.Softmax(dim=0)
        self.params = []
        for h in self.hidden_layers:
            self.params += list(h.parameters())
        for o in self.output_layers:
            self.params += list(o.parameters())
            
    # Forward propogate input.
    def forward(self, x):
        for hidden in self.hidden_layers:
            x = self.relu(hidden(x))
        outputs = []
        for out in self.output_layers:
            outputs.append(self.relu(out(x)))
        return outputs

# %%
# Exploratory agent.
class AGENT:
    
    # Constructor.
    def __init__(self, state_size, action_size, layer_count, step_size, learning_rate, gamma, t_device, s_device):
        self.state_size = state_size
        self.action_size = action_size
        self.layer_count = layer_count
        self.step_size = step_size
        self.learning_rate = learning_rate
        self.gamma = gamma
        self.t_device = t_device
        self.s_device = s_device
        self.age = 1
        self.node_levels = [[]]
        self.policy_map = POLICY_NET(state_size, action_size, layer_count, step_size, t_device)
        self.optimizer = torch.optim.Adam(self.policy_map.params, lr=learning_rate)
        self.loss_func = nn.CrossEntropyLoss()
        
    # Generates score biased training data.
    def get_score_training_data(self):
        pairings = []
        for level in self.node_levels:
            for node in level:
                if len(node.forward_links) > 0:
                    link = node.forward_links[0]
                    for l in node.forward_links:
                        if link.reward < l.reward:
                            link = l
                    if link.reward > 0:
                        pairings.append((torch.Tensor.float(torch.from_numpy(node.state)), link.copy_actions(), link.reward))
        pairings.sort(key = lambda x: x[2], reverse=True)
        pairings = pairings[:int(len(pairings) / 2)]
        rand.shuffle(pairings)
        inputs = []
        outputs = [[] for _ in range(self.step_size)]
        for p in pairings:
            inputs.append(p[0])
            for i in range(self.step_size):
                outputs[i].append(p[1][i])
        return inputs, outputs
    
    # Generates distance biased training data.
    def get_distance_training_data(self):
        pairings = []
        for level in self.node_levels:
            for node in level:
                if len(node.forward_links) > 0:
                    link = node.forward_links[0]
                    for l in node.forward_links:
                        if link.distance < l.distance:
                            link = l
                    if link.distance > 0: # Might want to change to cutting off on score not sure.
                        pairings.append((torch.Tensor.float(torch.from_numpy(node.state)), link.copy_actions(), link.distance))
        pairings.sort(key = lambda x: x[2], reverse=True)
        pairings = pairings[:int(len(pairings) / 2)]
        rand.shuffle(pairings)
        inputs = []
        outputs = [[] for _ in range(self.step_size)]
        for p in pairings:
            inputs.append(p[0])
            for i in range(self.step_size):
                outputs[i].append(p[1][i])
        return inputs, outputs
    
    # Generates distance and score biased training data.
    def get_composite_training_data(self):
        pairings = []
        for level in self.node_levels:
            for node in level:
                if len(node.forward_links) > 0:
                    link = node.forward_links[0]
                    for l in node.forward_links:
                        if (link.reward + 0.01) * link.distance < (l.reward + 0.01) * l.distance:
                            link = l
                    if link.reward > 0:
                        pairings.append((torch.Tensor.float(torch.from_numpy(node.state)), link.copy_actions(), (link.reward + 0.01) * link.distance))
        pairings.sort(key = lambda x: x[2], reverse=True)
        pairings = pairings[:int(len(pairings) / 2)]
        rand.shuffle(pairings)
        inputs = []
        outputs = [[] for _ in range(self.step_size)]
        for p in pairings:
            inputs.append(p[0])
            for i in range(self.step_size):
                outputs[i].append(p[1][i])
        return inputs, outputs
    
    # Train policy network.
    def train_policy_network(self, batch_size=1024, epochs=50):
        #inputs, outputs = self.get_score_training_data()
        #inputs, outputs = self.get_distance_training_data()
        inputs, outputs = self.get_composite_training_data()
        batches = []
        position = 0
        batch = ([],[[] for _ in range(self.step_size)])
        while position < len(inputs):
            batch[0].append(inputs[position])
            for i in range(len(batch[1])):
                batch[1][i].append(outputs[i][position])
            position += 1
            if len(batch[0]) >= batch_size:
                batches.append(batch)
                batch = ([],[[] for _ in range(self.step_size)])
        if len(batch) > 0:
            batches.append(batch)
        for e in range(epochs):
            for i in range(len(batches)):
                inputs = torch.stack(batches[i][0])
                outputs = [torch.Tensor(o).long() for o in batches[i][1]]
                out = self.policy_map(inputs)
                loss = None
                for j in range(len(outputs)):
                    if loss is None:
                        loss = self.loss_func(out[j], outputs[j])
                    else:
                        loss += self.loss_func(out[j], outputs[j])
                print('\rEPOCH {}/{} | BATCH {}/{} | CURRENT BATCH COUNT {} | LOSS {}'.format(e+1, epochs, i+1, len(batches), len(batches[i][0]), loss.detach().cpu().numpy()), end='')
                loss.backward()
                self.optimizer.step()
            
        
    # Plays a game.
    def play_game(self, env, render=False):
        done = False
        previous_node = None
        action = 0
        score = 0
        inner_score = 0 # Score inside inner steps.
        overall_step = 0
        step = 0
        depth = 0
        first_step = True
        lives = 4
        action_queue = None
        env.reset()
        prev_root_count = len(self.node_levels[0])
        while not done:
            if first_step:
                observation, reward, done, info = env.step(action)
                state = observation
                found = False
                for n in self.node_levels[0]:
                    if n.is_same(state):
                        previous_node = n
                        found = True
                        break
                if not found:
                    previous_node = NODE(state, self.age)
                    self.node_levels[0].append(previous_node)
                tensor = torch.Tensor.float(torch.from_numpy(state))
                dists = self.policy_map(tensor)
                action_queue = []
                for d in dists:
                    if rand.uniform(0,1) > self.gamma or min(d) < 0 or sum(d) == 0:
                        action_queue.append(rand.randint(0, self.action_size - 1))
                    else:
                        distribution = torch.distributions.categorical.Categorical(d)
                        action_queue.append(int(distribution.sample()))
                first_step = False
            else:
                action = action_queue[step]
                observation, reward, done, info = env.step(action)
                score += reward
                inner_score += reward
                state = observation
                step += 1
                if step == self.step_size:
                    depth += 1
                    current_node = None
                    if depth < len(self.node_levels):
                        found = False
                        for n in self.node_levels[depth]:
                            if n.is_same(state):
                                current_node = n
                                found = True
                                break
                        if not found:
                            current_node = NODE(state, self.age)
                            self.node_levels[depth].append(current_node)
                    else:
                        current_node = NODE(state, self.age)
                        self.node_levels.append([current_node])
                    previous_node.construct_link(current_node, inner_score, action_queue)
                    step = 0
                    inner_score = 0
                    tensor = torch.Tensor.float(torch.from_numpy(state))
                    dists = self.policy_map(tensor)
                    action_queue = []
                    try_rand = rand.uniform(0,1)
                    for d in dists:
                        if try_rand > self.gamma or min(d) < 0 or sum(d) == 0:
                            action_queue.append(rand.randint(0, self.action_size - 1))
                        else:
                            distribution = torch.distributions.categorical.Categorical(d)
                            action_queue.append(int(distribution.sample()))
                    previous_node = current_node
            print('\rSTEP {} | SCORE {} | DEPTH {} | ROOTS {} | AGE {} | RATIO {:0.4f} | ADDED {}\t\t'.format(overall_step, score, depth, len(self.node_levels[0]), self.age, len(self.node_levels[0])/self.age, len(self.node_levels[0])-prev_root_count), end = '')
            if render:
                env.render()
            if info['ale.lives'] != lives or done:
                lives = info['ale.lives']
                previous_node = None
                action = 0
                inner_score = 0 # Score inside inner steps.
                step = 0
                depth = 0
                first_step = True
                action_queue = None
            overall_step += 1
        self.age += 1

# %%
agent = AGENT(128, 14, 10, 5, 0.01, 0.9, torch.device('cpu'), torch.device('cpu'))

# %%
import gym
env = gym.make('KungFuMaster-ram-v0')

# %%
while True:
    agent.play_game(env, True)
    print()
    if agent.age % 10 == 0:
        agent.train_policy_network()
        print()
# Out:
# STEP 38 | SCORE 0.0 | DEPTH 7 | ROOTS 1 | AGE 1 | RATIO 1.0000 | ADDED 1
# c:\users\max9613\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: overflow encountered in ubyte_scalars
#   if sys.path[0] == '':
# STEP 1294 | SCORE 600.0 | DEPTH 46 | ROOTS 4 | AGE 1 | RATIO 4.0000 | ADDED 4
# STEP 1454 | SCORE 600.0 | DEPTH 63 | ROOTS 8 | AGE 2 | RATIO 4.0000 | ADDED 4
# STEP 1132 | SCORE 400.0 | DEPTH 64 | ROOTS 12 | AGE 3 | RATIO 4.0000 | ADDED 4
# STEP 809 | SCORE 100.0 | DEPTH 30 | ROOTS 16 | AGE 4 | RATIO 4.0000 | ADDED 4
# STEP 1442 | SCORE 800.0 | DEPTH 76 | ROOTS 20 | AGE 5 | RATIO 4.0000 | ADDED 4
# STEP 1287 | SCORE 400.0 | DEPTH 61 | ROOTS 24 | AGE 6 | RATIO 4.0000 | ADDED 4
# STEP 1066 | SCORE 600.0 | DEPTH 31 | ROOTS 27 | AGE 7 | RATIO 3.8571 | ADDED 3
# STEP 941 | SCORE 700.0 | DEPTH 39 | ROOTS 31 | AGE 8 | RATIO 3.8750 | ADDED 4
# STEP 1348 | SCORE 300.0 | DEPTH 65 | ROOTS 35 | AGE 9 | RATIO 3.8889 | ADDED 4
# EPOCH 50/50 | BATCH 1/1 | CURRENT BATCH COUNT 13 | LOSS 10.241255760192871
# STEP 1730 | SCORE 2300.0 | DEPTH 107 | ROOTS 39 | AGE 10 | RATIO 3.9000 | ADDED 4
# STEP 1607 | SCORE 2800.0 | DEPTH 108 | ROOTS 43 | AGE 11 | RATIO 3.9091 | ADDED 4
# STEP 1605 | SCORE 2000.0 | DEPTH 60 | ROOTS 47 | AGE 12 | RATIO 3.9167 | ADDED 4
# STEP 1620 | SCORE 2600.0 | DEPTH 62 | ROOTS 51 | AGE 13 | RATIO 3.9231 | ADDED 4
# STEP 1637 | SCORE 2700.0 | DEPTH 52 | ROOTS 55 | AGE 14 | RATIO 3.9286 | ADDED 4
# STEP 1970 | SCORE 3100.0 | DEPTH 71 | ROOTS 59 | AGE 15 | RATIO 3.9333 | ADDED 4
# STEP 1314 | SCORE 800.0 | DEPTH 93 | ROOTS 63 | AGE 16 | RATIO 3.9375 | ADDED 4
# STEP 1665 | SCORE 2000.0 | DEPTH 82 | ROOTS 67 | AGE 17 | RATIO 3.9412 | ADDED 4
# STEP 1488 | SCORE 2400.0 | DEPTH 82 | ROOTS 71 | AGE 18 | RATIO 3.9444 | ADDED 4
# STEP 1885 | SCORE 3100.0 | DEPTH 78 | ROOTS 75 | AGE 19 | RATIO 3.9474 | ADDED 4
# EPOCH 50/50 | BATCH 1/1 | CURRENT BATCH COUNT 76 | LOSS 9.1041164398193361
# STEP 1980 | SCORE 4600.0 | DEPTH 104 | ROOTS 79 | AGE 20 | RATIO 3.9500 | ADDED 4
# STEP 1724 | SCORE 2100.0 | DEPTH 70 | ROOTS 83 | AGE 21 | RATIO 3.9524 | ADDED 4
# STEP 1661 | SCORE 1200.0 | DEPTH 65 | ROOTS 87 | AGE 22 | RATIO 3.9545 | ADDED 4
# STEP 1379 | SCORE 1700.0 | DEPTH 30 | ROOTS 91 | AGE 23 | RATIO 3.9565 | ADDED 4
# STEP 1881 | SCORE 3800.0 | DEPTH 55 | ROOTS 95 | AGE 24 | RATIO 3.9583 | ADDED 4
# STEP 1310 | SCORE 1300.0 | DEPTH 69 | ROOTS 99 | AGE 25 | RATIO 3.9600 | ADDED 4
# STEP 1665 | SCORE 2400.0 | DEPTH 85 | ROOTS 103 | AGE 26 | RATIO 3.9615 | ADDED 4
# STEP 1690 | SCORE 3100.0 | DEPTH 24 | ROOTS 107 | AGE 27 | RATIO 3.9630 | ADDED 4
# STEP 1644 | SCORE 2200.0 | DEPTH 53 | ROOTS 111 | AGE 28 | RATIO 3.9643 | ADDED 4
# STEP 1522 | SCORE 2100.0 | DEPTH 52 | ROOTS 115 | AGE 29 | RATIO 3.9655 | ADDED 4
# EPOCH 50/50 | BATCH 1/1 | CURRENT BATCH COUNT 144 | LOSS 9.5051975250244148
# STEP 1331 | SCORE 500.0 | DEPTH 46 | ROOTS 119 | AGE 30 | RATIO 3.9667 | ADDED 4
# STEP 2103 | SCORE 4400.0 | DEPTH 141 | ROOTS 123 | AGE 31 | RATIO 3.9677 | ADDED 4
# STEP 1883 | SCORE 3000.0 | DEPTH 71 | ROOTS 127 | AGE 32 | RATIO 3.9688 | ADDED 4
# STEP 2035 | SCORE 4500.0 | DEPTH 134 | ROOTS 131 | AGE 33 | RATIO 3.9697 | ADDED 4
# STEP 1292 | SCORE 800.0 | DEPTH 71 | ROOTS 135 | AGE 34 | RATIO 3.9706 | ADDED 4
# STEP 1875 | SCORE 2500.0 | DEPTH 94 | ROOTS 139 | AGE 35 | RATIO 3.9714 | ADDED 4
# STEP 2168 | SCORE 3000.0 | DEPTH 90 | ROOTS 142 | AGE 36 | RATIO 3.9444 | ADDED 3
# STEP 1767 | SCORE 1400.0 | DEPTH 127 | ROOTS 146 | AGE 37 | RATIO 3.9459 | ADDED 4
# STEP 1823 | SCORE 2700.0 | DEPTH 85 | ROOTS 150 | AGE 38 | RATIO 3.9474 | ADDED 4
# STEP 1544 | SCORE 1700.0 | DEPTH 74 | ROOTS 154 | AGE 39 | RATIO 3.9487 | ADDED 4
# EPOCH 50/50 | BATCH 1/1 | CURRENT BATCH COUNT 209 | LOSS 8.966534614562988
# STEP 1342 | SCORE 2500.0 | DEPTH 47 | ROOTS 158 | AGE 40 | RATIO 3.9500 | ADDED 4
# STEP 2221 | SCORE 4100.0 | DEPTH 107 | ROOTS 162 | AGE 41 | RATIO 3.9512 | ADDED 4
# STEP 1610 | SCORE 2600.0 | DEPTH 100 | ROOTS 166 | AGE 42 | RATIO 3.9524 | ADDED 4
# STEP 1599 | SCORE 1800.0 | DEPTH 80 | ROOTS 170 | AGE 43 | RATIO 3.9535 | ADDED 4
# STEP 1531 | SCORE 2900.0 | DEPTH 76 | ROOTS 174 | AGE 44 | RATIO 3.9545 | ADDED 4
# STEP 1623 | SCORE 2700.0 | DEPTH 99 | ROOTS 177 | AGE 45 | RATIO 3.9333 | ADDED 3
# STEP 1557 | SCORE 1800.0 | DEPTH 101 | ROOTS 180 | AGE 46 | RATIO 3.9130 | ADDED 3
# STEP 1307 | SCORE 3100.0 | DEPTH 48 | ROOTS 183 | AGE 47 | RATIO 3.8936 | ADDED 3
# STEP 1527 | SCORE 3100.0 | DEPTH 45 | ROOTS 187 | AGE 48 | RATIO 3.8958 | ADDED 4
# STEP 1061 | SCORE 400.0 | DEPTH 62 | ROOTS 191 | AGE 49 | RATIO 3.8980 | ADDED 4
# EPOCH 50/50 | BATCH 1/1 | CURRENT BATCH COUNT 271 | LOSS 13.894304275512695
# STEP 1800 | SCORE 2400.0 | DEPTH 97 | ROOTS 195 | AGE 50 | RATIO 3.9000 | ADDED 4
# STEP 1548 | SCORE 1900.0 | DEPTH 97 | ROOTS 198 | AGE 51 | RATIO 3.8824 | ADDED 3
# STEP 2016 | SCORE 3300.0 | DEPTH 101 | ROOTS 202 | AGE 52 | RATIO 3.8846 | ADDED 4
# STEP 1475 | SCORE 3200.0 | DEPTH 85 | ROOTS 206 | AGE 53 | RATIO 3.8868 | ADDED 4
# STEP 2226 | SCORE 5400.0 | DEPTH 120 | ROOTS 210 | AGE 54 | RATIO 3.8889 | ADDED 4
# STEP 1513 | SCORE 2200.0 | DEPTH 62 | ROOTS 214 | AGE 55 | RATIO 3.8909 | ADDED 4
# STEP 1825 | SCORE 2900.0 | DEPTH 74 | ROOTS 217 | AGE 56 | RATIO 3.8750 | ADDED 3
# STEP 1738 | SCORE 2200.0 | DEPTH 72 | ROOTS 221 | AGE 57 | RATIO 3.8772 | ADDED 4
# STEP 2133 | SCORE 3800.0 | DEPTH 65 | ROOTS 224 | AGE 58 | RATIO 3.8621 | ADDED 3
# STEP 1249 | SCORE 600.0 | DEPTH 49 | ROOTS 227 | AGE 59 | RATIO 3.8475 | ADDED 3
# EPOCH 50/50 | BATCH 1/1 | CURRENT BATCH COUNT 344 | LOSS 9.0078067779541021
# STEP 1743 | SCORE 2000.0 | DEPTH 94 | ROOTS 231 | AGE 60 | RATIO 3.8500 | ADDED 4
# STEP 1457 | SCORE 2300.0 | DEPTH 85 | ROOTS 235 | AGE 61 | RATIO 3.8525 | ADDED 4
# STEP 1374 | SCORE 2100.0 | DEPTH 61 | ROOTS 239 | AGE 62 | RATIO 3.8548 | ADDED 4
# STEP 1540 | SCORE 2500.0 | DEPTH 69 | ROOTS 243 | AGE 63 | RATIO 3.8571 | ADDED 4
# STEP 1792 | SCORE 3000.0 | DEPTH 94 | ROOTS 247 | AGE 64 | RATIO 3.8594 | ADDED 4
# STEP 1853 | SCORE 3300.0 | DEPTH 72 | ROOTS 250 | AGE 65 | RATIO 3.8462 | ADDED 3
# STEP 1526 | SCORE 2200.0 | DEPTH 65 | ROOTS 254 | AGE 66 | RATIO 3.8485 | ADDED 4
# STEP 1382 | SCORE 1300.0 | DEPTH 51 | ROOTS 258 | AGE 67 | RATIO 3.8507 | ADDED 4
# STEP 1476 | SCORE 1500.0 | DEPTH 36 | ROOTS 262 | AGE 68 | RATIO 3.8529 | ADDED 4
# STEP 1908 | SCORE 3200.0 | DEPTH 97 | ROOTS 265 | AGE 69 | RATIO 3.8406 | ADDED 3
# EPOCH 50/50 | BATCH 1/1 | CURRENT BATCH COUNT 405 | LOSS 9.3302812576293953
# STEP 1603 | SCORE 1400.0 | DEPTH 81 | ROOTS 269 | AGE 70 | RATIO 3.8429 | ADDED 4
# STEP 1392 | SCORE 2000.0 | DEPTH 46 | ROOTS 273 | AGE 71 | RATIO 3.8451 | ADDED 4
# STEP 1654 | SCORE 2400.0 | DEPTH 86 | ROOTS 277 | AGE 72 | RATIO 3.8472 | ADDED 4
# STEP 1428 | SCORE 1000.0 | DEPTH 69 | ROOTS 281 | AGE 73 | RATIO 3.8493 | ADDED 4
# STEP 1560 | SCORE 1600.0 | DEPTH 93 | ROOTS 285 | AGE 74 | RATIO 3.8514 | ADDED 4
# STEP 1721 | SCORE 2200.0 | DEPTH 119 | ROOTS 289 | AGE 75 | RATIO 3.8533 | ADDED 4
# STEP 1838 | SCORE 2300.0 | DEPTH 122 | ROOTS 292 | AGE 76 | RATIO 3.8421 | ADDED 3
# STEP 1728 | SCORE 2800.0 | DEPTH 71 | ROOTS 295 | AGE 77 | RATIO 3.8312 | ADDED 3
# STEP 1157 | SCORE 1700.0 | DEPTH 79 | ROOTS 299 | AGE 78 | RATIO 3.8333 | ADDED 4
# STEP 1384 | SCORE 1600.0 | DEPTH 51 | ROOTS 303 | AGE 79 | RATIO 3.8354 | ADDED 4
# EPOCH 50/50 | BATCH 1/1 | CURRENT BATCH COUNT 454 | LOSS 8.513628005981445
# STEP 1252 | SCORE 1400.0 | DEPTH 77 | ROOTS 307 | AGE 80 | RATIO 3.8375 | ADDED 4
# STEP 1315 | SCORE 1800.0 | DEPTH 84 | ROOTS 311 | AGE 81 | RATIO 3.8395 | ADDED 4
# STEP 1609 | SCORE 2400.0 | DEPTH 124 | ROOTS 315 | AGE 82 | RATIO 3.8415 | ADDED 4
# STEP 1820 | SCORE 2800.0 | DEPTH 92 | ROOTS 319 | AGE 83 | RATIO 3.8434 | ADDED 4
# STEP 2033 | SCORE 1900.0 | DEPTH 140 | ROOTS 322 | AGE 84 | RATIO 3.8333 | ADDED 3
# STEP 3322 | SCORE 2700.0 | DEPTH 452 | ROOTS 325 | AGE 85 | RATIO 3.8235 | ADDED 3
# STEP 1478 | SCORE 1200.0 | DEPTH 63 | ROOTS 329 | AGE 86 | RATIO 3.8256 | ADDED 4
# STEP 1843 | SCORE 3600.0 | DEPTH 76 | ROOTS 333 | AGE 87 | RATIO 3.8276 | ADDED 4
# STEP 1851 | SCORE 2100.0 | DEPTH 86 | ROOTS 337 | AGE 88 | RATIO 3.8295 | ADDED 4
# STEP 1465 | SCORE 1200.0 | DEPTH 65 | ROOTS 341 | AGE 89 | RATIO 3.8315 | ADDED 4
# EPOCH 50/50 | BATCH 1/1 | CURRENT BATCH COUNT 509 | LOSS 8.458018302917483
# STEP 1469 | SCORE 1900.0 | DEPTH 56 | ROOTS 345 | AGE 90 | RATIO 3.8333 | ADDED 4
# STEP 1925 | SCORE 4300.0 | DEPTH 87 | ROOTS 349 | AGE 91 | RATIO 3.8352 | ADDED 4
# STEP 1694 | SCORE 2000.0 | DEPTH 91 | ROOTS 353 | AGE 92 | RATIO 3.8370 | ADDED 4
# STEP 1811 | SCORE 3100.0 | DEPTH 84 | ROOTS 357 | AGE 93 | RATIO 3.8387 | ADDED 4
# STEP 1964 | SCORE 2600.0 | DEPTH 101 | ROOTS 361 | AGE 94 | RATIO 3.8404 | ADDED 4
# STEP 1752 | SCORE 3300.0 | DEPTH 110 | ROOTS 365 | AGE 95 | RATIO 3.8421 | ADDED 4
# STEP 1531 | SCORE 1100.0 | DEPTH 70 | ROOTS 369 | AGE 96 | RATIO 3.8438 | ADDED 4
# STEP 1522 | SCORE 2000.0 | DEPTH 89 | ROOTS 373 | AGE 97 | RATIO 3.8454 | ADDED 4
# STEP 2071 | SCORE 3300.0 | DEPTH 116 | ROOTS 377 | AGE 98 | RATIO 3.8469 | ADDED 4
# STEP 1490 | SCORE 2800.0 | DEPTH 89 | ROOTS 381 | AGE 99 | RATIO 3.8485 | ADDED 4
# EPOCH 50/50 | BATCH 1/1 | CURRENT BATCH COUNT 577 | LOSS 8.653231620788574
# STEP 1094 | SCORE 400.0 | DEPTH 39 | ROOTS 384 | AGE 100 | RATIO 3.8400 | ADDED 3
# STEP 1662 | SCORE 1500.0 | DEPTH 83 | ROOTS 388 | AGE 101 | RATIO 3.8416 | ADDED 4
# STEP 1560 | SCORE 1800.0 | DEPTH 44 | ROOTS 391 | AGE 102 | RATIO 3.8333 | ADDED 3
# STEP 1473 | SCORE 1600.0 | DEPTH 64 | ROOTS 394 | AGE 103 | RATIO 3.8252 | ADDED 3
# STEP 1710 | SCORE 2400.0 | DEPTH 45 | ROOTS 398 | AGE 104 | RATIO 3.8269 | ADDED 4
# STEP 1511 | SCORE 2100.0 | DEPTH 71 | ROOTS 402 | AGE 105 | RATIO 3.8286 | ADDED 4
# STEP 1501 | SCORE 2000.0 | DEPTH 85 | ROOTS 406 | AGE 106 | RATIO 3.8302 | ADDED 4
# STEP 2027 | SCORE 2700.0 | DEPTH 102 | ROOTS 409 | AGE 107 | RATIO 3.8224 | ADDED 3
# STEP 1679 | SCORE 1200.0 | DEPTH 99 | ROOTS 413 | AGE 108 | RATIO 3.8241 | ADDED 4
# STEP 1721 | SCORE 2900.0 | DEPTH 49 | ROOTS 417 | AGE 109 | RATIO 3.8257 | ADDED 4
# EPOCH 50/50 | BATCH 1/1 | CURRENT BATCH COUNT 626 | LOSS 8.721074104309082
# STEP 1416 | SCORE 1400.0 | DEPTH 61 | ROOTS 421 | AGE 110 | RATIO 3.8273 | ADDED 4
# STEP 1604 | SCORE 1600.0 | DEPTH 71 | ROOTS 425 | AGE 111 | RATIO 3.8288 | ADDED 4
# STEP 1558 | SCORE 1500.0 | DEPTH 49 | ROOTS 429 | AGE 112 | RATIO 3.8304 | ADDED 4
# STEP 1641 | SCORE 2200.0 | DEPTH 97 | ROOTS 433 | AGE 113 | RATIO 3.8319 | ADDED 4
# STEP 1726 | SCORE 2100.0 | DEPTH 68 | ROOTS 437 | AGE 114 | RATIO 3.8333 | ADDED 4
# STEP 1562 | SCORE 1600.0 | DEPTH 85 | ROOTS 441 | AGE 115 | RATIO 3.8348 | ADDED 4
# STEP 1430 | SCORE 1600.0 | DEPTH 64 | ROOTS 445 | AGE 116 | RATIO 3.8362 | ADDED 4
# STEP 1503 | SCORE 1800.0 | DEPTH 82 | ROOTS 449 | AGE 117 | RATIO 3.8376 | ADDED 4
# STEP 1504 | SCORE 1500.0 | DEPTH 75 | ROOTS 453 | AGE 118 | RATIO 3.8390 | ADDED 4
# STEP 2183 | SCORE 5200.0 | DEPTH 90 | ROOTS 457 | AGE 119 | RATIO 3.8403 | ADDED 4
# EPOCH 50/50 | BATCH 1/1 | CURRENT BATCH COUNT 678 | LOSS 8.677044868469238
# STEP 1744 | SCORE 2500.0 | DEPTH 127 | ROOTS 460 | AGE 120 | RATIO 3.8333 | ADDED 3
# STEP 2259 | SCORE 3900.0 | DEPTH 110 | ROOTS 464 | AGE 121 | RATIO 3.8347 | ADDED 4
# STEP 1451 | SCORE 2200.0 | DEPTH 67 | ROOTS 468 | AGE 122 | RATIO 3.8361 | ADDED 4
# STEP 1804 | SCORE 2600.0 | DEPTH 75 | ROOTS 472 | AGE 123 | RATIO 3.8374 | ADDED 4
# STEP 1448 | SCORE 1600.0 | DEPTH 93 | ROOTS 475 | AGE 124 | RATIO 3.8306 | ADDED 3
# STEP 1971 | SCORE 2300.0 | DEPTH 83 | ROOTS 479 | AGE 125 | RATIO 3.8320 | ADDED 4
# STEP 1866 | SCORE 3600.0 | DEPTH 132 | ROOTS 482 | AGE 126 | RATIO 3.8254 | ADDED 3
# STEP 1496 | SCORE 1600.0 | DEPTH 61 | ROOTS 486 | AGE 127 | RATIO 3.8268 | ADDED 4
# STEP 1954 | SCORE 2200.0 | DEPTH 108 | ROOTS 490 | AGE 128 | RATIO 3.8281 | ADDED 4
# STEP 1294 | SCORE 1000.0 | DEPTH 49 | ROOTS 493 | AGE 129 | RATIO 3.8217 | ADDED 3
# EPOCH 50/50 | BATCH 1/1 | CURRENT BATCH COUNT 740 | LOSS 8.546475410461426
# STEP 1576 | SCORE 2000.0 | DEPTH 106 | ROOTS 496 | AGE 130 | RATIO 3.8154 | ADDED 3
# STEP 1397 | SCORE 1200.0 | DEPTH 101 | ROOTS 499 | AGE 131 | RATIO 3.8092 | ADDED 3
# STEP 1817 | SCORE 2200.0 | DEPTH 81 | ROOTS 502 | AGE 132 | RATIO 3.8030 | ADDED 3
# STEP 1279 | SCORE 1800.0 | DEPTH 77 | ROOTS 505 | AGE 133 | RATIO 3.7970 | ADDED 3
# STEP 1469 | SCORE 2300.0 | DEPTH 53 | ROOTS 508 | AGE 134 | RATIO 3.7910 | ADDED 3
# STEP 1804 | SCORE 3500.0 | DEPTH 129 | ROOTS 511 | AGE 135 | RATIO 3.7852 | ADDED 3
# STEP 1625 | SCORE 2400.0 | DEPTH 83 | ROOTS 514 | AGE 136 | RATIO 3.7794 | ADDED 3
# STEP 1633 | SCORE 2100.0 | DEPTH 135 | ROOTS 518 | AGE 137 | RATIO 3.7810 | ADDED 4
# STEP 1507 | SCORE 1200.0 | DEPTH 58 | ROOTS 522 | AGE 138 | RATIO 3.7826 | ADDED 4
# STEP 1463 | SCORE 1000.0 | DEPTH 101 | ROOTS 525 | AGE 139 | RATIO 3.7770 | ADDED 3
# EPOCH 50/50 | BATCH 1/1 | CURRENT BATCH COUNT 792 | LOSS 8.871241569519043
# STEP 1699 | SCORE 2900.0 | DEPTH 61 | ROOTS 528 | AGE 140 | RATIO 3.7714 | ADDED 3
# STEP 1557 | SCORE 1600.0 | DEPTH 109 | ROOTS 531 | AGE 141 | RATIO 3.7660 | ADDED 3
# STEP 1845 | SCORE 3300.0 | DEPTH 100 | ROOTS 535 | AGE 142 | RATIO 3.7676 | ADDED 4
# STEP 1321 | SCORE 800.0 | DEPTH 75 | ROOTS 539 | AGE 143 | RATIO 3.7692 | ADDED 4
# STEP 1899 | SCORE 3300.0 | DEPTH 85 | ROOTS 543 | AGE 144 | RATIO 3.7708 | ADDED 4
# STEP 1326 | SCORE 1100.0 | DEPTH 61 | ROOTS 547 | AGE 145 | RATIO 3.7724 | ADDED 4
# STEP 1618 | SCORE 2000.0 | DEPTH 75 | ROOTS 551 | AGE 146 | RATIO 3.7740 | ADDED 4
# STEP 1569 | SCORE 1700.0 | DEPTH 51 | ROOTS 554 | AGE 147 | RATIO 3.7687 | ADDED 3
# STEP 1695 | SCORE 3100.0 | DEPTH 82 | ROOTS 557 | AGE 148 | RATIO 3.7635 | ADDED 3
# STEP 1833 | SCORE 1700.0 | DEPTH 81 | ROOTS 561 | AGE 149 | RATIO 3.7651 | ADDED 4
# EPOCH 50/50 | BATCH 1/1 | CURRENT BATCH COUNT 847 | LOSS 9.005716323852539
# STEP 1936 | SCORE 1800.0 | DEPTH 110 | ROOTS 564 | AGE 150 | RATIO 3.7600 | ADDED 3
# STEP 1774 | SCORE 1800.0 | DEPTH 106 | ROOTS 567 | AGE 151 | RATIO 3.7550 | ADDED 3
# STEP 2189 | SCORE 3600.0 | DEPTH 85 | ROOTS 571 | AGE 152 | RATIO 3.7566 | ADDED 4
# STEP 1334 | SCORE 400.0 | DEPTH 61 | ROOTS 575 | AGE 153 | RATIO 3.7582 | ADDED 4
# STEP 1622 | SCORE 1600.0 | DEPTH 86 | ROOTS 579 | AGE 154 | RATIO 3.7597 | ADDED 4
# STEP 1996 | SCORE 3300.0 | DEPTH 93 | ROOTS 583 | AGE 155 | RATIO 3.7613 | ADDED 4
# STEP 1759 | SCORE 2700.0 | DEPTH 75 | ROOTS 587 | AGE 156 | RATIO 3.7628 | ADDED 4
# STEP 1745 | SCORE 1700.0 | DEPTH 66 | ROOTS 591 | AGE 157 | RATIO 3.7643 | ADDED 4
# STEP 1926 | SCORE 3900.0 | DEPTH 45 | ROOTS 595 | AGE 158 | RATIO 3.7658 | ADDED 4
# STEP 1832 | SCORE 2400.0 | DEPTH 111 | ROOTS 598 | AGE 159 | RATIO 3.7610 | ADDED 3
# EPOCH 50/50 | BATCH 1/1 | CURRENT BATCH COUNT 908 | LOSS 8.754371643066406
# STEP 2173 | SCORE 2800.0 | DEPTH 107 | ROOTS 602 | AGE 160 | RATIO 3.7625 | ADDED 4
# STEP 1596 | SCORE 2200.0 | DEPTH 68 | ROOTS 606 | AGE 161 | RATIO 3.7640 | ADDED 4
# STEP 1763 | SCORE 2000.0 | DEPTH 89 | ROOTS 610 | AGE 162 | RATIO 3.7654 | ADDED 4
# STEP 1614 | SCORE 2000.0 | DEPTH 81 | ROOTS 614 | AGE 163 | RATIO 3.7669 | ADDED 4
# STEP 2025 | SCORE 3200.0 | DEPTH 155 | ROOTS 617 | AGE 164 | RATIO 3.7622 | ADDED 3
# STEP 2409 | SCORE 4500.0 | DEPTH 116 | ROOTS 621 | AGE 165 | RATIO 3.7636 | ADDED 4
# STEP 1378 | SCORE 1400.0 | DEPTH 23 | ROOTS 625 | AGE 166 | RATIO 3.7651 | ADDED 4
# STEP 1330 | SCORE 1000.0 | DEPTH 100 | ROOTS 628 | AGE 167 | RATIO 3.7605 | ADDED 3
# STEP 1719 | SCORE 2100.0 | DEPTH 67 | ROOTS 632 | AGE 168 | RATIO 3.7619 | ADDED 4
# STEP 1697 | SCORE 2000.0 | DEPTH 113 | ROOTS 636 | AGE 169 | RATIO 3.7633 | ADDED 4
# EPOCH 50/50 | BATCH 1/1 | CURRENT BATCH COUNT 967 | LOSS 8.718743324279785
# STEP 1677 | SCORE 2500.0 | DEPTH 77 | ROOTS 640 | AGE 170 | RATIO 3.7647 | ADDED 4
# STEP 1434 | SCORE 1400.0 | DEPTH 79 | ROOTS 644 | AGE 171 | RATIO 3.7661 | ADDED 4
# STEP 1583 | SCORE 1400.0 | DEPTH 95 | ROOTS 647 | AGE 172 | RATIO 3.7616 | ADDED 3
# STEP 1491 | SCORE 1900.0 | DEPTH 68 | ROOTS 651 | AGE 173 | RATIO 3.7630 | ADDED 4
# STEP 1847 | SCORE 1900.0 | DEPTH 141 | ROOTS 655 | AGE 174 | RATIO 3.7644 | ADDED 4
# STEP 1052 | SCORE 1000.0 | DEPTH 47 | ROOTS 659 | AGE 175 | RATIO 3.7657 | ADDED 4
# STEP 3303 | SCORE 2400.0 | DEPTH 71 | ROOTS 663 | AGE 176 | RATIO 3.7670 | ADDED 4
# STEP 1549 | SCORE 2500.0 | DEPTH 72 | ROOTS 667 | AGE 177 | RATIO 3.7684 | ADDED 4
# STEP 1642 | SCORE 2400.0 | DEPTH 69 | ROOTS 670 | AGE 178 | RATIO 3.7640 | ADDED 3
# STEP 1941 | SCORE 2800.0 | DEPTH 68 | ROOTS 673 | AGE 179 | RATIO 3.7598 | ADDED 3
# EPOCH 50/50 | BATCH 1/1 | CURRENT BATCH COUNT 1018 | LOSS 9.141818046569824
# STEP 1684 | SCORE 1200.0 | DEPTH 60 | ROOTS 676 | AGE 180 | RATIO 3.7556 | ADDED 3
# STEP 1891 | SCORE 2200.0 | DEPTH 68 | ROOTS 679 | AGE 181 | RATIO 3.7514 | ADDED 3
# STEP 1595 | SCORE 2500.0 | DEPTH 67 | ROOTS 682 | AGE 182 | RATIO 3.7473 | ADDED 3
# STEP 1710 | SCORE 1600.0 | DEPTH 115 | ROOTS 686 | AGE 183 | RATIO 3.7486 | ADDED 4
# STEP 1545 | SCORE 1300.0 | DEPTH 44 | ROOTS 689 | AGE 184 | RATIO 3.7446 | ADDED 3
# STEP 1756 | SCORE 1900.0 | DEPTH 70 | ROOTS 692 | AGE 185 | RATIO 3.7405 | ADDED 3
# STEP 1836 | SCORE 3400.0 | DEPTH 79 | ROOTS 695 | AGE 186 | RATIO 3.7366 | ADDED 3
# STEP 2122 | SCORE 4300.0 | DEPTH 109 | ROOTS 698 | AGE 187 | RATIO 3.7326 | ADDED 3
# STEP 1736 | SCORE 2000.0 | DEPTH 82 | ROOTS 701 | AGE 188 | RATIO 3.7287 | ADDED 3
# STEP 1636 | SCORE 1200.0 | DEPTH 79 | ROOTS 704 | AGE 189 | RATIO 3.7249 | ADDED 3
# EPOCH 50/50 | BATCH 2/2 | CURRENT BATCH COUNT 51 | LOSS 9.66259098052978531
# STEP 1451 | SCORE 2100.0 | DEPTH 41 | ROOTS 708 | AGE 190 | RATIO 3.7263 | ADDED 4
# STEP 1611 | SCORE 2800.0 | DEPTH 61 | ROOTS 712 | AGE 191 | RATIO 3.7277 | ADDED 4
# STEP 1582 | SCORE 1500.0 | DEPTH 45 | ROOTS 716 | AGE 192 | RATIO 3.7292 | ADDED 4
# STEP 1540 | SCORE 2800.0 | DEPTH 85 | ROOTS 719 | AGE 193 | RATIO 3.7254 | ADDED 3
# STEP 1658 | SCORE 3400.0 | DEPTH 50 | ROOTS 722 | AGE 194 | RATIO 3.7216 | ADDED 3
# STEP 1957 | SCORE 3900.0 | DEPTH 85 | ROOTS 725 | AGE 195 | RATIO 3.7179 | ADDED 3
# STEP 1764 | SCORE 1900.0 | DEPTH 67 | ROOTS 728 | AGE 196 | RATIO 3.7143 | ADDED 3
# STEP 1444 | SCORE 800.0 | DEPTH 71 | ROOTS 732 | AGE 197 | RATIO 3.7157 | ADDED 4
# STEP 1622 | SCORE 2200.0 | DEPTH 117 | ROOTS 735 | AGE 198 | RATIO 3.7121 | ADDED 3
# STEP 1344 | SCORE 1800.0 | DEPTH 35 | ROOTS 739 | AGE 199 | RATIO 3.7136 | ADDED 4
# EPOCH 50/50 | BATCH 2/2 | CURRENT BATCH COUNT 112 | LOSS 8.6707105636596682
# STEP 1882 | SCORE 3600.0 | DEPTH 128 | ROOTS 743 | AGE 200 | RATIO 3.7150 | ADDED 4
# STEP 1663 | SCORE 1800.0 | DEPTH 85 | ROOTS 746 | AGE 201 | RATIO 3.7114 | ADDED 3
# STEP 1492 | SCORE 2000.0 | DEPTH 75 | ROOTS 750 | AGE 202 | RATIO 3.7129 | ADDED 4
# STEP 1837 | SCORE 2500.0 | DEPTH 84 | ROOTS 754 | AGE 203 | RATIO 3.7143 | ADDED 4
# STEP 1549 | SCORE 2400.0 | DEPTH 51 | ROOTS 758 | AGE 204 | RATIO 3.7157 | ADDED 4
# STEP 1631 | SCORE 1700.0 | DEPTH 96 | ROOTS 762 | AGE 205 | RATIO 3.7171 | ADDED 4
# STEP 1535 | SCORE 1900.0 | DEPTH 56 | ROOTS 765 | AGE 206 | RATIO 3.7136 | ADDED 3
# STEP 1563 | SCORE 1700.0 | DEPTH 88 | ROOTS 769 | AGE 207 | RATIO 3.7150 | ADDED 4
# STEP 1834 | SCORE 700.0 | DEPTH 105 | ROOTS 772 | AGE 208 | RATIO 3.7115 | ADDED 3
# STEP 1520 | SCORE 1300.0 | DEPTH 74 | ROOTS 775 | AGE 209 | RATIO 3.7081 | ADDED 3
# EPOCH 50/50 | BATCH 2/2 | CURRENT BATCH COUNT 164 | LOSS 10.491641998291016
# STEP 1338 | SCORE 1000.0 | DEPTH 72 | ROOTS 779 | AGE 210 | RATIO 3.7095 | ADDED 4
# STEP 1454 | SCORE 1400.0 | DEPTH 62 | ROOTS 782 | AGE 211 | RATIO 3.7062 | ADDED 3
# STEP 1741 | SCORE 1200.0 | DEPTH 61 | ROOTS 786 | AGE 212 | RATIO 3.7075 | ADDED 4
# STEP 1495 | SCORE 1400.0 | DEPTH 114 | ROOTS 790 | AGE 213 | RATIO 3.7089 | ADDED 4
# STEP 1607 | SCORE 2200.0 | DEPTH 64 | ROOTS 794 | AGE 214 | RATIO 3.7103 | ADDED 4
# STEP 1948 | SCORE 4200.0 | DEPTH 96 | ROOTS 797 | AGE 215 | RATIO 3.7070 | ADDED 3
# STEP 1495 | SCORE 1400.0 | DEPTH 98 | ROOTS 800 | AGE 216 | RATIO 3.7037 | ADDED 3
# STEP 1610 | SCORE 2400.0 | DEPTH 84 | ROOTS 804 | AGE 217 | RATIO 3.7051 | ADDED 4
# STEP 1235 | SCORE 1400.0 | DEPTH 52 | ROOTS 808 | AGE 218 | RATIO 3.7064 | ADDED 4
# STEP 1677 | SCORE 3100.0 | DEPTH 79 | ROOTS 812 | AGE 219 | RATIO 3.7078 | ADDED 4
# EPOCH 50/50 | BATCH 2/2 | CURRENT BATCH COUNT 214 | LOSS 9.7025518417358455
# STEP 1534 | SCORE 2000.0 | DEPTH 67 | ROOTS 815 | AGE 220 | RATIO 3.7045 | ADDED 3
# STEP 1584 | SCORE 1600.0 | DEPTH 77 | ROOTS 818 | AGE 221 | RATIO 3.7014 | ADDED 3
# STEP 1622 | SCORE 2400.0 | DEPTH 71 | ROOTS 822 | AGE 222 | RATIO 3.7027 | ADDED 4
# STEP 1852 | SCORE 2700.0 | DEPTH 75 | ROOTS 825 | AGE 223 | RATIO 3.6996 | ADDED 3
# STEP 1720 | SCORE 2500.0 | DEPTH 60 | ROOTS 829 | AGE 224 | RATIO 3.7009 | ADDED 4
# STEP 1647 | SCORE 2400.0 | DEPTH 84 | ROOTS 832 | AGE 225 | RATIO 3.6978 | ADDED 3
# STEP 1954 | SCORE 3500.0 | DEPTH 101 | ROOTS 835 | AGE 226 | RATIO 3.6947 | ADDED 3
# STEP 1673 | SCORE 1100.0 | DEPTH 69 | ROOTS 838 | AGE 227 | RATIO 3.6916 | ADDED 3
# STEP 1177 | SCORE 800.0 | DEPTH 73 | ROOTS 841 | AGE 228 | RATIO 3.6886 | ADDED 3
# STEP 2011 | SCORE 2800.0 | DEPTH 60 | ROOTS 844 | AGE 229 | RATIO 3.6856 | ADDED 3
# EPOCH 50/50 | BATCH 2/2 | CURRENT BATCH COUNT 272 | LOSS 9.75821495056152335
# STEP 1375 | SCORE 1400.0 | DEPTH 95 | ROOTS 848 | AGE 230 | RATIO 3.6870 | ADDED 4
# STEP 1528 | SCORE 1300.0 | DEPTH 78 | ROOTS 851 | AGE 231 | RATIO 3.6840 | ADDED 3
# STEP 1854 | SCORE 2100.0 | DEPTH 96 | ROOTS 855 | AGE 232 | RATIO 3.6853 | ADDED 4
# STEP 1866 | SCORE 3000.0 | DEPTH 73 | ROOTS 858 | AGE 233 | RATIO 3.6824 | ADDED 3
# STEP 1584 | SCORE 2200.0 | DEPTH 80 | ROOTS 861 | AGE 234 | RATIO 3.6795 | ADDED 3
# STEP 1404 | SCORE 2500.0 | DEPTH 76 | ROOTS 865 | AGE 235 | RATIO 3.6809 | ADDED 4
# STEP 2029 | SCORE 2400.0 | DEPTH 78 | ROOTS 868 | AGE 236 | RATIO 3.6780 | ADDED 3
# STEP 1392 | SCORE 900.0 | DEPTH 58 | ROOTS 871 | AGE 237 | RATIO 3.6751 | ADDED 3
# STEP 1196 | SCORE 1600.0 | DEPTH 61 | ROOTS 875 | AGE 238 | RATIO 3.6765 | ADDED 4
# STEP 1660 | SCORE 2100.0 | DEPTH 59 | ROOTS 878 | AGE 239 | RATIO 3.6736 | ADDED 3
# EPOCH 50/50 | BATCH 2/2 | CURRENT BATCH COUNT 323 | LOSS 10.3678340911865239
# STEP 1171 | SCORE 800.0 | DEPTH 50 | ROOTS 882 | AGE 240 | RATIO 3.6750 | ADDED 4
# STEP 1728 | SCORE 2900.0 | DEPTH 83 | ROOTS 886 | AGE 241 | RATIO 3.6763 | ADDED 4
# STEP 1442 | SCORE 900.0 | DEPTH 33 | ROOTS 889 | AGE 242 | RATIO 3.6736 | ADDED 3
# STEP 1536 | SCORE 1200.0 | DEPTH 66 | ROOTS 892 | AGE 243 | RATIO 3.6708 | ADDED 3
# STEP 2213 | SCORE 6200.0 | DEPTH 107 | ROOTS 896 | AGE 244 | RATIO 3.6721 | ADDED 4
# STEP 1949 | SCORE 3200.0 | DEPTH 158 | ROOTS 899 | AGE 245 | RATIO 3.6694 | ADDED 3
# STEP 1958 | SCORE 3300.0 | DEPTH 103 | ROOTS 903 | AGE 246 | RATIO 3.6707 | ADDED 4
# STEP 1596 | SCORE 1200.0 | DEPTH 70 | ROOTS 906 | AGE 247 | RATIO 3.6680 | ADDED 3
# STEP 1585 | SCORE 1400.0 | DEPTH 73 | ROOTS 909 | AGE 248 | RATIO 3.6653 | ADDED 3
# STEP 1639 | SCORE 3900.0 | DEPTH 89 | ROOTS 912 | AGE 249 | RATIO 3.6627 | ADDED 3
# EPOCH 50/50 | BATCH 2/2 | CURRENT BATCH COUNT 386 | LOSS 9.80656623840332155
# STEP 1672 | SCORE 1000.0 | DEPTH 80 | ROOTS 915 | AGE 250 | RATIO 3.6600 | ADDED 3
# STEP 1740 | SCORE 3300.0 | DEPTH 72 | ROOTS 919 | AGE 251 | RATIO 3.6614 | ADDED 4
# STEP 1429 | SCORE 2000.0 | DEPTH 71 | ROOTS 922 | AGE 252 | RATIO 3.6587 | ADDED 3
# STEP 1806 | SCORE 4400.0 | DEPTH 78 | ROOTS 925 | AGE 253 | RATIO 3.6561 | ADDED 3
# STEP 1199 | SCORE 400.0 | DEPTH 66 | ROOTS 928 | AGE 254 | RATIO 3.6535 | ADDED 3
# STEP 2135 | SCORE 5200.0 | DEPTH 90 | ROOTS 931 | AGE 255 | RATIO 3.6510 | ADDED 3
# STEP 1948 | SCORE 3300.0 | DEPTH 77 | ROOTS 934 | AGE 256 | RATIO 3.6484 | ADDED 3
# STEP 1444 | SCORE 800.0 | DEPTH 71 | ROOTS 937 | AGE 257 | RATIO 3.6459 | ADDED 3
# STEP 1662 | SCORE 2200.0 | DEPTH 55 | ROOTS 940 | AGE 258 | RATIO 3.6434 | ADDED 3
# STEP 1076 | SCORE 900.0 | DEPTH 39 | ROOTS 943 | AGE 259 | RATIO 3.6409 | ADDED 3
# EPOCH 50/50 | BATCH 2/2 | CURRENT BATCH COUNT 447 | LOSS 10.7333478927612395
# STEP 1383 | SCORE 1300.0 | DEPTH 49 | ROOTS 947 | AGE 260 | RATIO 3.6423 | ADDED 4
# STEP 1360 | SCORE 1200.0 | DEPTH 67 | ROOTS 950 | AGE 261 | RATIO 3.6398 | ADDED 3
# STEP 1899 | SCORE 2100.0 | DEPTH 58 | ROOTS 953 | AGE 262 | RATIO 3.6374 | ADDED 3
# STEP 1960 | SCORE 2500.0 | DEPTH 109 | ROOTS 956 | AGE 263 | RATIO 3.6350 | ADDED 3
# STEP 1631 | SCORE 2900.0 | DEPTH 104 | ROOTS 959 | AGE 264 | RATIO 3.6326 | ADDED 3
# STEP 1749 | SCORE 3200.0 | DEPTH 131 | ROOTS 962 | AGE 265 | RATIO 3.6302 | ADDED 3
# STEP 1486 | SCORE 1000.0 | DEPTH 72 | ROOTS 966 | AGE 266 | RATIO 3.6316 | ADDED 4
# STEP 1578 | SCORE 2500.0 | DEPTH 59 | ROOTS 970 | AGE 267 | RATIO 3.6330 | ADDED 4
# STEP 1716 | SCORE 1900.0 | DEPTH 68 | ROOTS 974 | AGE 268 | RATIO 3.6343 | ADDED 4
# STEP 1551 | SCORE 1800.0 | DEPTH 58 | ROOTS 977 | AGE 269 | RATIO 3.6320 | ADDED 3
# EPOCH 50/50 | BATCH 2/2 | CURRENT BATCH COUNT 500 | LOSS 10.6020317077636725
# STEP 2018 | SCORE 2200.0 | DEPTH 126 | ROOTS 981 | AGE 270 | RATIO 3.6333 | ADDED 4
# STEP 1614 | SCORE 2500.0 | DEPTH 111 | ROOTS 985 | AGE 271 | RATIO 3.6347 | ADDED 4
# STEP 1828 | SCORE 2000.0 | DEPTH 56 | ROOTS 989 | AGE 272 | RATIO 3.6360 | ADDED 4
# STEP 1683 | SCORE 3000.0 | DEPTH 138 | ROOTS 993 | AGE 273 | RATIO 3.6374 | ADDED 4
# STEP 1330 | SCORE 1100.0 | DEPTH 68 | ROOTS 996 | AGE 274 | RATIO 3.6350 | ADDED 3
# STEP 1892 | SCORE 3000.0 | DEPTH 100 | ROOTS 1000 | AGE 275 | RATIO 3.6364 | ADDED 4
# STEP 1642 | SCORE 1800.0 | DEPTH 62 | ROOTS 1004 | AGE 276 | RATIO 3.6377 | ADDED 4
# STEP 1985 | SCORE 3200.0 | DEPTH 73 | ROOTS 1007 | AGE 277 | RATIO 3.6354 | ADDED 3
# STEP 1670 | SCORE 2800.0 | DEPTH 62 | ROOTS 1010 | AGE 278 | RATIO 3.6331 | ADDED 3
# STEP 1973 | SCORE 2100.0 | DEPTH 84 | ROOTS 1013 | AGE 279 | RATIO 3.6308 | ADDED 3
# EPOCH 50/50 | BATCH 2/2 | CURRENT BATCH COUNT 564 | LOSS 11.1388587951660165
# STEP 1576 | SCORE 1300.0 | DEPTH 54 | ROOTS 1016 | AGE 280 | RATIO 3.6286 | ADDED 3
# STEP 1696 | SCORE 700.0 | DEPTH 62 | ROOTS 1019 | AGE 281 | RATIO 3.6263 | ADDED 3
# STEP 1335 | SCORE 2200.0 | DEPTH 57 | ROOTS 1022 | AGE 282 | RATIO 3.6241 | ADDED 3
# STEP 2095 | SCORE 3000.0 | DEPTH 102 | ROOTS 1026 | AGE 283 | RATIO 3.6254 | ADDED 4
# STEP 1378 | SCORE 800.0 | DEPTH 67 | ROOTS 1029 | AGE 284 | RATIO 3.6232 | ADDED 3
# STEP 1805 | SCORE 2700.0 | DEPTH 103 | ROOTS 1033 | AGE 285 | RATIO 3.6246 | ADDED 4
# STEP 1762 | SCORE 2700.0 | DEPTH 91 | ROOTS 1037 | AGE 286 | RATIO 3.6259 | ADDED 4
# STEP 1872 | SCORE 3300.0 | DEPTH 79 | ROOTS 1040 | AGE 287 | RATIO 3.6237 | ADDED 3
# STEP 1768 | SCORE 2100.0 | DEPTH 55 | ROOTS 1043 | AGE 288 | RATIO 3.6215 | ADDED 3
# STEP 1239 | SCORE 1400.0 | DEPTH 47 | ROOTS 1047 | AGE 289 | RATIO 3.6228 | ADDED 4
# EPOCH 50/50 | BATCH 2/2 | CURRENT BATCH COUNT 617 | LOSS 10.5765457153320312
# STEP 1760 | SCORE 2800.0 | DEPTH 70 | ROOTS 1050 | AGE 290 | RATIO 3.6207 | ADDED 3
# STEP 1804 | SCORE 2000.0 | DEPTH 85 | ROOTS 1054 | AGE 291 | RATIO 3.6220 | ADDED 4
# STEP 1595 | SCORE 1600.0 | DEPTH 90 | ROOTS 1057 | AGE 292 | RATIO 3.6199 | ADDED 3
# STEP 1682 | SCORE 1700.0 | DEPTH 61 | ROOTS 1061 | AGE 293 | RATIO 3.6212 | ADDED 4
# STEP 1646 | SCORE 3000.0 | DEPTH 104 | ROOTS 1064 | AGE 294 | RATIO 3.6190 | ADDED 3
# STEP 1386 | SCORE 500.0 | DEPTH 74 | ROOTS 1068 | AGE 295 | RATIO 3.6203 | ADDED 4
# STEP 1879 | SCORE 3200.0 | DEPTH 108 | ROOTS 1071 | AGE 296 | RATIO 3.6182 | ADDED 3
# STEP 2719 | SCORE 6000.0 | DEPTH 164 | ROOTS 1074 | AGE 297 | RATIO 3.6162 | ADDED 3
# STEP 1503 | SCORE 1400.0 | DEPTH 48 | ROOTS 1078 | AGE 298 | RATIO 3.6174 | ADDED 4
# STEP 1745 | SCORE 3100.0 | DEPTH 59 | ROOTS 1081 | AGE 299 | RATIO 3.6154 | ADDED 3
# EPOCH 50/50 | BATCH 2/2 | CURRENT BATCH COUNT 677 | LOSS 10.9118289947509773
# STEP 1524 | SCORE 2100.0 | DEPTH 72 | ROOTS 1085 | AGE 300 | RATIO 3.6167 | ADDED 4
# STEP 1335 | SCORE 2300.0 | DEPTH 47 | ROOTS 1089 | AGE 301 | RATIO 3.6179 | ADDED 4
# STEP 1616 | SCORE 3600.0 | DEPTH 76 | ROOTS 1092 | AGE 302 | RATIO 3.6159 | ADDED 3
# STEP 1603 | SCORE 1200.0 | DEPTH 40 | ROOTS 1096 | AGE 303 | RATIO 3.6172 | ADDED 4
# STEP 1699 | SCORE 3300.0 | DEPTH 50 | ROOTS 1099 | AGE 304 | RATIO 3.6151 | ADDED 3
# STEP 1667 | SCORE 2700.0 | DEPTH 117 | ROOTS 1102 | AGE 305 | RATIO 3.6131 | ADDED 3
# STEP 1622 | SCORE 1700.0 | DEPTH 50 | ROOTS 1106 | AGE 306 | RATIO 3.6144 | ADDED 4
# STEP 1915 | SCORE 3000.0 | DEPTH 119 | ROOTS 1110 | AGE 307 | RATIO 3.6156 | ADDED 4
# STEP 1718 | SCORE 3200.0 | DEPTH 86 | ROOTS 1113 | AGE 308 | RATIO 3.6136 | ADDED 3
# STEP 1503 | SCORE 1700.0 | DEPTH 72 | ROOTS 1117 | AGE 309 | RATIO 3.6149 | ADDED 4
# EPOCH 50/50 | BATCH 2/2 | CURRENT BATCH COUNT 739 | LOSS 11.6193218231201173
# STEP 2061 | SCORE 4200.0 | DEPTH 99 | ROOTS 1120 | AGE 310 | RATIO 3.6129 | ADDED 3
# STEP 1962 | SCORE 3700.0 | DEPTH 100 | ROOTS 1124 | AGE 311 | RATIO 3.6141 | ADDED 4
# STEP 1394 | SCORE 1600.0 | DEPTH 90 | ROOTS 1128 | AGE 312 | RATIO 3.6154 | ADDED 4
# STEP 2382 | SCORE 4900.0 | DEPTH 143 | ROOTS 1132 | AGE 313 | RATIO 3.6166 | ADDED 4
# STEP 1443 | SCORE 2200.0 | DEPTH 53 | ROOTS 1135 | AGE 314 | RATIO 3.6146 | ADDED 3
# STEP 1821 | SCORE 3600.0 | DEPTH 96 | ROOTS 1139 | AGE 315 | RATIO 3.6159 | ADDED 4
# STEP 1649 | SCORE 2000.0 | DEPTH 103 | ROOTS 1142 | AGE 316 | RATIO 3.6139 | ADDED 3
# STEP 1885 | SCORE 3300.0 | DEPTH 113 | ROOTS 1145 | AGE 317 | RATIO 3.6120 | ADDED 3
# STEP 1198 | SCORE 600.0 | DEPTH 68 | ROOTS 1149 | AGE 318 | RATIO 3.6132 | ADDED 4
# STEP 1919 | SCORE 3900.0 | DEPTH 140 | ROOTS 1152 | AGE 319 | RATIO 3.6113 | ADDED 3
# EPOCH 50/50 | BATCH 2/2 | CURRENT BATCH COUNT 817 | LOSS 11.6661872863769535
# STEP 1572 | SCORE 2600.0 | DEPTH 77 | ROOTS 1156 | AGE 320 | RATIO 3.6125 | ADDED 4
# STEP 1087 | SCORE 1000.0 | DEPTH 36 | ROOTS 1160 | AGE 321 | RATIO 3.6137 | ADDED 4
# STEP 1808 | SCORE 1900.0 | DEPTH 75 | ROOTS 1164 | AGE 322 | RATIO 3.6149 | ADDED 4
# STEP 1446 | SCORE 1700.0 | DEPTH 65 | ROOTS 1167 | AGE 323 | RATIO 3.6130 | ADDED 3
# STEP 1622 | SCORE 1800.0 | DEPTH 48 | ROOTS 1170 | AGE 324 | RATIO 3.6111 | ADDED 3
# STEP 2317 | SCORE 2600.0 | DEPTH 121 | ROOTS 1173 | AGE 325 | RATIO 3.6092 | ADDED 3
# STEP 1874 | SCORE 2000.0 | DEPTH 75 | ROOTS 1176 | AGE 326 | RATIO 3.6074 | ADDED 3
# STEP 1541 | SCORE 1800.0 | DEPTH 61 | ROOTS 1180 | AGE 327 | RATIO 3.6086 | ADDED 4
# STEP 1820 | SCORE 3900.0 | DEPTH 80 | ROOTS 1183 | AGE 328 | RATIO 3.6067 | ADDED 3
# STEP 2043 | SCORE 3500.0 | DEPTH 90 | ROOTS 1187 | AGE 329 | RATIO 3.6079 | ADDED 4
# EPOCH 50/50 | BATCH 2/2 | CURRENT BATCH COUNT 876 | LOSS 11.1475162506103523
# STEP 1627 | SCORE 3300.0 | DEPTH 105 | ROOTS 1190 | AGE 330 | RATIO 3.6061 | ADDED 3
# STEP 1641 | SCORE 2000.0 | DEPTH 60 | ROOTS 1193 | AGE 331 | RATIO 3.6042 | ADDED 3
# STEP 1538 | SCORE 1400.0 | DEPTH 75 | ROOTS 1197 | AGE 332 | RATIO 3.6054 | ADDED 4
# STEP 1804 | SCORE 1100.0 | DEPTH 109 | ROOTS 1201 | AGE 333 | RATIO 3.6066 | ADDED 4
# STEP 1653 | SCORE 1400.0 | DEPTH 120 | ROOTS 1204 | AGE 334 | RATIO 3.6048 | ADDED 3
# STEP 1854 | SCORE 2400.0 | DEPTH 100 | ROOTS 1208 | AGE 335 | RATIO 3.6060 | ADDED 4
# STEP 1967 | SCORE 4900.0 | DEPTH 140 | ROOTS 1211 | AGE 336 | RATIO 3.6042 | ADDED 3
# STEP 1539 | SCORE 1800.0 | DEPTH 61 | ROOTS 1214 | AGE 337 | RATIO 3.6024 | ADDED 3
# STEP 2985 | SCORE 2500.0 | DEPTH 57 | ROOTS 1217 | AGE 338 | RATIO 3.6006 | ADDED 3
# STEP 1539 | SCORE 2500.0 | DEPTH 89 | ROOTS 1221 | AGE 339 | RATIO 3.6018 | ADDED 4
# EPOCH 50/50 | BATCH 2/2 | CURRENT BATCH COUNT 935 | LOSS 11.1307973861694342
# STEP 1556 | SCORE 1000.0 | DEPTH 77 | ROOTS 1224 | AGE 340 | RATIO 3.6000 | ADDED 3
# STEP 1682 | SCORE 1600.0 | DEPTH 54 | ROOTS 1227 | AGE 341 | RATIO 3.5982 | ADDED 3
# STEP 2182 | SCORE 5300.0 | DEPTH 57 | ROOTS 1230 | AGE 342 | RATIO 3.5965 | ADDED 3
# STEP 1615 | SCORE 3000.0 | DEPTH 49 | ROOTS 1233 | AGE 343 | RATIO 3.5948 | ADDED 3
# STEP 1621 | SCORE 800.0 | DEPTH 90 | ROOTS 1236 | AGE 344 | RATIO 3.5930 | ADDED 3
# STEP 1655 | SCORE 2500.0 | DEPTH 55 | ROOTS 1239 | AGE 345 | RATIO 3.5913 | ADDED 3
# STEP 1000 | SCORE 400.0 | DEPTH 50 | ROOTS 1243 | AGE 346 | RATIO 3.5925 | ADDED 4
# STEP 1281 | SCORE 1200.0 | DEPTH 32 | ROOTS 1246 | AGE 347 | RATIO 3.5908 | ADDED 3
# STEP 1665 | SCORE 2600.0 | DEPTH 86 | ROOTS 1250 | AGE 348 | RATIO 3.5920 | ADDED 4
# STEP 1684 | SCORE 2600.0 | DEPTH 66 | ROOTS 1253 | AGE 349 | RATIO 3.5903 | ADDED 3
# EPOCH 50/50 | BATCH 2/2 | CURRENT BATCH COUNT 987 | LOSS 11.7608060836792172
# STEP 1883 | SCORE 2800.0 | DEPTH 109 | ROOTS 1257 | AGE 350 | RATIO 3.5914 | ADDED 4
# STEP 1869 | SCORE 2300.0 | DEPTH 98 | ROOTS 1260 | AGE 351 | RATIO 3.5897 | ADDED 3
# STEP 1782 | SCORE 2600.0 | DEPTH 79 | ROOTS 1263 | AGE 352 | RATIO 3.5881 | ADDED 3
# STEP 1565 | SCORE 2800.0 | DEPTH 65 | ROOTS 1266 | AGE 353 | RATIO 3.5864 | ADDED 3
# STEP 1249 | SCORE 1000.0 | DEPTH 74 | ROOTS 1270 | AGE 354 | RATIO 3.5876 | ADDED 4
# STEP 1680 | SCORE 2100.0 | DEPTH 92 | ROOTS 1273 | AGE 355 | RATIO 3.5859 | ADDED 3
# STEP 1543 | SCORE 800.0 | DEPTH 79 | ROOTS 1276 | AGE 356 | RATIO 3.5843 | ADDED 3
# STEP 2120 | SCORE 3000.0 | DEPTH 105 | ROOTS 1279 | AGE 357 | RATIO 3.5826 | ADDED 3
# STEP 1464 | SCORE 1700.0 | DEPTH 83 | ROOTS 1283 | AGE 358 | RATIO 3.5838 | ADDED 4
# STEP 1559 | SCORE 2800.0 | DEPTH 57 | ROOTS 1286 | AGE 359 | RATIO 3.5822 | ADDED 3
# EPOCH 50/50 | BATCH 3/3 | CURRENT BATCH COUNT 19 | LOSS 11.62235736846923875
# STEP 1954 | SCORE 3100.0 | DEPTH 139 | ROOTS 1289 | AGE 360 | RATIO 3.5806 | ADDED 3
# STEP 2080 | SCORE 3900.0 | DEPTH 109 | ROOTS 1292 | AGE 361 | RATIO 3.5789 | ADDED 3
# STEP 1608 | SCORE 3300.0 | DEPTH 88 | ROOTS 1295 | AGE 362 | RATIO 3.5773 | ADDED 3
# STEP 1373 | SCORE 1300.0 | DEPTH 33 | ROOTS 1298 | AGE 363 | RATIO 3.5758 | ADDED 3
# STEP 1575 | SCORE 2000.0 | DEPTH 75 | ROOTS 1302 | AGE 364 | RATIO 3.5769 | ADDED 4
# STEP 1582 | SCORE 1700.0 | DEPTH 88 | ROOTS 1306 | AGE 365 | RATIO 3.5781 | ADDED 4
# STEP 1752 | SCORE 2800.0 | DEPTH 71 | ROOTS 1310 | AGE 366 | RATIO 3.5792 | ADDED 4
# STEP 1437 | SCORE 2200.0 | DEPTH 38 | ROOTS 1314 | AGE 367 | RATIO 3.5804 | ADDED 4
# STEP 2140 | SCORE 3900.0 | DEPTH 134 | ROOTS 1317 | AGE 368 | RATIO 3.5788 | ADDED 3
# STEP 2041 | SCORE 4100.0 | DEPTH 93 | ROOTS 1320 | AGE 369 | RATIO 3.5772 | ADDED 3
# EPOCH 50/50 | BATCH 3/3 | CURRENT BATCH COUNT 92 | LOSS 11.22237586975097772
# STEP 1999 | SCORE 4300.0 | DEPTH 138 | ROOTS 1324 | AGE 370 | RATIO 3.5784 | ADDED 4
# STEP 1807 | SCORE 3200.0 | DEPTH 61 | ROOTS 1328 | AGE 371 | RATIO 3.5795 | ADDED 4
# STEP 2280 | SCORE 3500.0 | DEPTH 123 | ROOTS 1331 | AGE 372 | RATIO 3.5780 | ADDED 3
# STEP 1474 | SCORE 1400.0 | DEPTH 96 | ROOTS 1334 | AGE 373 | RATIO 3.5764 | ADDED 3
# STEP 1812 | SCORE 2300.0 | DEPTH 87 | ROOTS 1337 | AGE 374 | RATIO 3.5749 | ADDED 3
# STEP 2189 | SCORE 4900.0 | DEPTH 83 | ROOTS 1340 | AGE 375 | RATIO 3.5733 | ADDED 3
# STEP 1552 | SCORE 2600.0 | DEPTH 90 | ROOTS 1343 | AGE 376 | RATIO 3.5718 | ADDED 3
# STEP 1751 | SCORE 2100.0 | DEPTH 81 | ROOTS 1346 | AGE 377 | RATIO 3.5703 | ADDED 3
# STEP 1628 | SCORE 3400.0 | DEPTH 94 | ROOTS 1349 | AGE 378 | RATIO 3.5688 | ADDED 3
# STEP 2379 | SCORE 6900.0 | DEPTH 130 | ROOTS 1352 | AGE 379 | RATIO 3.5673 | ADDED 3
# EPOCH 50/50 | BATCH 3/3 | CURRENT BATCH COUNT 181 | LOSS 12.6983842849731452
# STEP 1256 | SCORE 2400.0 | DEPTH 74 | ROOTS 1356 | AGE 380 | RATIO 3.5684 | ADDED 4
# STEP 1900 | SCORE 3900.0 | DEPTH 75 | ROOTS 1359 | AGE 381 | RATIO 3.5669 | ADDED 3
# STEP 1642 | SCORE 2700.0 | DEPTH 87 | ROOTS 1362 | AGE 382 | RATIO 3.5654 | ADDED 3
# STEP 1679 | SCORE 1900.0 | DEPTH 75 | ROOTS 1365 | AGE 383 | RATIO 3.5640 | ADDED 3
# STEP 1984 | SCORE 4700.0 | DEPTH 95 | ROOTS 1368 | AGE 384 | RATIO 3.5625 | ADDED 3
# STEP 1706 | SCORE 2700.0 | DEPTH 87 | ROOTS 1371 | AGE 385 | RATIO 3.5610 | ADDED 3
# STEP 2483 | SCORE 7300.0 | DEPTH 158 | ROOTS 1374 | AGE 386 | RATIO 3.5596 | ADDED 3
# STEP 1549 | SCORE 1800.0 | DEPTH 100 | ROOTS 1377 | AGE 387 | RATIO 3.5581 | ADDED 3
# STEP 1590 | SCORE 1200.0 | DEPTH 66 | ROOTS 1380 | AGE 388 | RATIO 3.5567 | ADDED 3
# STEP 1847 | SCORE 2400.0 | DEPTH 90 | ROOTS 1383 | AGE 389 | RATIO 3.5553 | ADDED 3
# EPOCH 50/50 | BATCH 3/3 | CURRENT BATCH COUNT 263 | LOSS 11.6647720336914061
# STEP 2235 | SCORE 4500.0 | DEPTH 125 | ROOTS 1386 | AGE 390 | RATIO 3.5538 | ADDED 3
# STEP 2799 | SCORE 7800.0 | DEPTH 138 | ROOTS 1390 | AGE 391 | RATIO 3.5550 | ADDED 4
# STEP 2162 | SCORE 5100.0 | DEPTH 130 | ROOTS 1394 | AGE 392 | RATIO 3.5561 | ADDED 4
# STEP 1852 | SCORE 4100.0 | DEPTH 82 | ROOTS 1398 | AGE 393 | RATIO 3.5573 | ADDED 4
# STEP 2041 | SCORE 4600.0 | DEPTH 160 | ROOTS 1401 | AGE 394 | RATIO 3.5558 | ADDED 3
# STEP 2269 | SCORE 4000.0 | DEPTH 181 | ROOTS 1405 | AGE 395 | RATIO 3.5570 | ADDED 4
# STEP 2036 | SCORE 4100.0 | DEPTH 72 | ROOTS 1409 | AGE 396 | RATIO 3.5581 | ADDED 4
# STEP 1960 | SCORE 4200.0 | DEPTH 73 | ROOTS 1413 | AGE 397 | RATIO 3.5592 | ADDED 4
# STEP 1675 | SCORE 2700.0 | DEPTH 55 | ROOTS 1417 | AGE 398 | RATIO 3.5603 | ADDED 4
# STEP 2016 | SCORE 4600.0 | DEPTH 132 | ROOTS 1421 | AGE 399 | RATIO 3.5614 | ADDED 4
# EPOCH 50/50 | BATCH 3/3 | CURRENT BATCH COUNT 384 | LOSS 11.9721736907958984
# STEP 1474 | SCORE 4100.0 | DEPTH 100 | ROOTS 1425 | AGE 400 | RATIO 3.5625 | ADDED 4
# STEP 2032 | SCORE 6800.0 | DEPTH 116 | ROOTS 1428 | AGE 401 | RATIO 3.5611 | ADDED 3
# STEP 2078 | SCORE 4800.0 | DEPTH 136 | ROOTS 1432 | AGE 402 | RATIO 3.5622 | ADDED 4
# STEP 1821 | SCORE 3100.0 | DEPTH 101 | ROOTS 1436 | AGE 403 | RATIO 3.5633 | ADDED 4
# STEP 2430 | SCORE 7300.0 | DEPTH 160 | ROOTS 1440 | AGE 404 | RATIO 3.5644 | ADDED 4
# STEP 2490 | SCORE 8600.0 | DEPTH 129 | ROOTS 1443 | AGE 405 | RATIO 3.5630 | ADDED 3
# STEP 1841 | SCORE 3900.0 | DEPTH 68 | ROOTS 1446 | AGE 406 | RATIO 3.5616 | ADDED 3
# STEP 1533 | SCORE 3500.0 | DEPTH 88 | ROOTS 1450 | AGE 407 | RATIO 3.5627 | ADDED 4
# STEP 1701 | SCORE 3300.0 | DEPTH 98 | ROOTS 1453 | AGE 408 | RATIO 3.5613 | ADDED 3
# STEP 1915 | SCORE 4400.0 | DEPTH 122 | ROOTS 1456 | AGE 409 | RATIO 3.5599 | ADDED 3
# EPOCH 50/50 | BATCH 3/3 | CURRENT BATCH COUNT 510 | LOSS 11.6247358322143557
# STEP 1739 | SCORE 3900.0 | DEPTH 71 | ROOTS 1459 | AGE 410 | RATIO 3.5585 | ADDED 3
# STEP 2232 | SCORE 7800.0 | DEPTH 93 | ROOTS 1462 | AGE 411 | RATIO 3.5572 | ADDED 3
# STEP 2291 | SCORE 6200.0 | DEPTH 99 | ROOTS 1466 | AGE 412 | RATIO 3.5583 | ADDED 4
# STEP 1839 | SCORE 2800.0 | DEPTH 92 | ROOTS 1470 | AGE 413 | RATIO 3.5593 | ADDED 4
# STEP 2566 | SCORE 7600.0 | DEPTH 126 | ROOTS 1473 | AGE 414 | RATIO 3.5580 | ADDED 3
# STEP 2510 | SCORE 8600.0 | DEPTH 114 | ROOTS 1476 | AGE 415 | RATIO 3.5566 | ADDED 3
# STEP 2012 | SCORE 3600.0 | DEPTH 103 | ROOTS 1480 | AGE 416 | RATIO 3.5577 | ADDED 4
# STEP 2252 | SCORE 5800.0 | DEPTH 67 | ROOTS 1483 | AGE 417 | RATIO 3.5564 | ADDED 3
# STEP 2578 | SCORE 7800.0 | DEPTH 87 | ROOTS 1486 | AGE 418 | RATIO 3.5550 | ADDED 3
# STEP 1904 | SCORE 3200.0 | DEPTH 112 | ROOTS 1489 | AGE 419 | RATIO 3.5537 | ADDED 3
# EPOCH 50/50 | BATCH 3/3 | CURRENT BATCH COUNT 654 | LOSS 12.0608367919921881
# STEP 1747 | SCORE 3300.0 | DEPTH 57 | ROOTS 1492 | AGE 420 | RATIO 3.5524 | ADDED 3
# STEP 4011 | SCORE 7100.0 | DEPTH 126 | ROOTS 1496 | AGE 421 | RATIO 3.5534 | ADDED 4
# STEP 2609 | SCORE 7900.0 | DEPTH 148 | ROOTS 1500 | AGE 422 | RATIO 3.5545 | ADDED 4
# STEP 2227 | SCORE 4800.0 | DEPTH 108 | ROOTS 1503 | AGE 423 | RATIO 3.5532 | ADDED 3
# STEP 2178 | SCORE 4900.0 | DEPTH 150 | ROOTS 1506 | AGE 424 | RATIO 3.5519 | ADDED 3
# STEP 1738 | SCORE 4100.0 | DEPTH 120 | ROOTS 1509 | AGE 425 | RATIO 3.5506 | ADDED 3
# STEP 2462 | SCORE 6000.0 | DEPTH 151 | ROOTS 1512 | AGE 426 | RATIO 3.5493 | ADDED 3
# STEP 1573 | SCORE 2700.0 | DEPTH 94 | ROOTS 1516 | AGE 427 | RATIO 3.5504 | ADDED 4
# STEP 2273 | SCORE 5500.0 | DEPTH 80 | ROOTS 1519 | AGE 428 | RATIO 3.5491 | ADDED 3
# STEP 2056 | SCORE 5900.0 | DEPTH 79 | ROOTS 1523 | AGE 429 | RATIO 3.5501 | ADDED 4
# EPOCH 50/50 | BATCH 3/3 | CURRENT BATCH COUNT 789 | LOSS 10.9500961303710944
# STEP 2179 | SCORE 7400.0 | DEPTH 81 | ROOTS 1527 | AGE 430 | RATIO 3.5512 | ADDED 4
# STEP 2113 | SCORE 6200.0 | DEPTH 71 | ROOTS 1530 | AGE 431 | RATIO 3.5499 | ADDED 3
# STEP 2187 | SCORE 4600.0 | DEPTH 99 | ROOTS 1533 | AGE 432 | RATIO 3.5486 | ADDED 3
# STEP 1661 | SCORE 3400.0 | DEPTH 63 | ROOTS 1536 | AGE 433 | RATIO 3.5473 | ADDED 3
# STEP 2141 | SCORE 6200.0 | DEPTH 57 | ROOTS 1539 | AGE 434 | RATIO 3.5461 | ADDED 3
# STEP 2920 | SCORE 6500.0 | DEPTH 67 | ROOTS 1543 | AGE 435 | RATIO 3.5471 | ADDED 4
# STEP 2379 | SCORE 5600.0 | DEPTH 146 | ROOTS 1547 | AGE 436 | RATIO 3.5482 | ADDED 4
# STEP 3066 | SCORE 5700.0 | DEPTH 190 | ROOTS 1550 | AGE 437 | RATIO 3.5469 | ADDED 3
# STEP 2526 | SCORE 9500.0 | DEPTH 142 | ROOTS 1554 | AGE 438 | RATIO 3.5479 | ADDED 4
# STEP 2415 | SCORE 5400.0 | DEPTH 105 | ROOTS 1558 | AGE 439 | RATIO 3.5490 | ADDED 4
# EPOCH 50/50 | BATCH 3/3 | CURRENT BATCH COUNT 940 | LOSS 11.7492866516113283
# STEP 1769 | SCORE 4100.0 | DEPTH 86 | ROOTS 1562 | AGE 440 | RATIO 3.5500 | ADDED 4
# STEP 1978 | SCORE 3200.0 | DEPTH 62 | ROOTS 1565 | AGE 441 | RATIO 3.5488 | ADDED 3
# STEP 1546 | SCORE 2600.0 | DEPTH 61 | ROOTS 1568 | AGE 442 | RATIO 3.5475 | ADDED 3
# STEP 1736 | SCORE 3200.0 | DEPTH 56 | ROOTS 1572 | AGE 443 | RATIO 3.5485 | ADDED 4
# STEP 2234 | SCORE 3800.0 | DEPTH 76 | ROOTS 1575 | AGE 444 | RATIO 3.5473 | ADDED 3
# STEP 1663 | SCORE 3600.0 | DEPTH 87 | ROOTS 1578 | AGE 445 | RATIO 3.5461 | ADDED 3
# STEP 2445 | SCORE 7000.0 | DEPTH 84 | ROOTS 1582 | AGE 446 | RATIO 3.5471 | ADDED 4
# STEP 1669 | SCORE 1800.0 | DEPTH 81 | ROOTS 1586 | AGE 447 | RATIO 3.5481 | ADDED 4
# STEP 2356 | SCORE 6400.0 | DEPTH 122 | ROOTS 1589 | AGE 448 | RATIO 3.5469 | ADDED 3
# STEP 1938 | SCORE 3400.0 | DEPTH 119 | ROOTS 1593 | AGE 449 | RATIO 3.5479 | ADDED 4
# EPOCH 50/50 | BATCH 4/4 | CURRENT BATCH COUNT 11 | LOSS 12.31524753570556639
# STEP 2435 | SCORE 7800.0 | DEPTH 108 | ROOTS 1597 | AGE 450 | RATIO 3.5489 | ADDED 4
# STEP 2020 | SCORE 5200.0 | DEPTH 142 | ROOTS 1600 | AGE 451 | RATIO 3.5477 | ADDED 3
# STEP 1789 | SCORE 4500.0 | DEPTH 96 | ROOTS 1604 | AGE 452 | RATIO 3.5487 | ADDED 4
# STEP 1665 | SCORE 3400.0 | DEPTH 68 | ROOTS 1607 | AGE 453 | RATIO 3.5475 | ADDED 3
# STEP 2042 | SCORE 3800.0 | DEPTH 120 | ROOTS 1610 | AGE 454 | RATIO 3.5463 | ADDED 3
# STEP 2189 | SCORE 7800.0 | DEPTH 40 | ROOTS 1614 | AGE 455 | RATIO 3.5473 | ADDED 4
# STEP 2539 | SCORE 6800.0 | DEPTH 118 | ROOTS 1618 | AGE 456 | RATIO 3.5482 | ADDED 4
# STEP 1719 | SCORE 3300.0 | DEPTH 103 | ROOTS 1621 | AGE 457 | RATIO 3.5470 | ADDED 3
# STEP 2104 | SCORE 2200.0 | DEPTH 82 | ROOTS 1625 | AGE 458 | RATIO 3.5480 | ADDED 4
# STEP 2213 | SCORE 5800.0 | DEPTH 184 | ROOTS 1628 | AGE 459 | RATIO 3.5468 | ADDED 3
# EPOCH 50/50 | BATCH 4/4 | CURRENT BATCH COUNT 136 | LOSS 12.1615438461303714
# STEP 1939 | SCORE 5200.0 | DEPTH 127 | ROOTS 1631 | AGE 460 | RATIO 3.5457 | ADDED 3
# STEP 2280 | SCORE 5800.0 | DEPTH 106 | ROOTS 1635 | AGE 461 | RATIO 3.5466 | ADDED 4
# STEP 2045 | SCORE 5000.0 | DEPTH 108 | ROOTS 1638 | AGE 462 | RATIO 3.5455 | ADDED 3
# STEP 1905 | SCORE 4800.0 | DEPTH 93 | ROOTS 1641 | AGE 463 | RATIO 3.5443 | ADDED 3
# STEP 2099 | SCORE 7000.0 | DEPTH 76 | ROOTS 1645 | AGE 464 | RATIO 3.5453 | ADDED 4
# STEP 1909 | SCORE 3600.0 | DEPTH 149 | ROOTS 1648 | AGE 465 | RATIO 3.5441 | ADDED 3
# STEP 1915 | SCORE 2500.0 | DEPTH 121 | ROOTS 1652 | AGE 466 | RATIO 3.5451 | ADDED 4
# STEP 1961 | SCORE 4400.0 | DEPTH 71 | ROOTS 1656 | AGE 467 | RATIO 3.5460 | ADDED 4
# STEP 1830 | SCORE 3600.0 | DEPTH 118 | ROOTS 1659 | AGE 468 | RATIO 3.5449 | ADDED 3
# STEP 2131 | SCORE 5400.0 | DEPTH 80 | ROOTS 1662 | AGE 469 | RATIO 3.5437 | ADDED 3
# EPOCH 50/50 | BATCH 4/4 | CURRENT BATCH COUNT 255 | LOSS 13.1075286865234389
# STEP 1687 | SCORE 3400.0 | DEPTH 74 | ROOTS 1665 | AGE 470 | RATIO 3.5426 | ADDED 3
# STEP 1521 | SCORE 2800.0 | DEPTH 69 | ROOTS 1668 | AGE 471 | RATIO 3.5414 | ADDED 3
# STEP 1870 | SCORE 4600.0 | DEPTH 68 | ROOTS 1672 | AGE 472 | RATIO 3.5424 | ADDED 4
# STEP 1996 | SCORE 4700.0 | DEPTH 57 | ROOTS 1675 | AGE 473 | RATIO 3.5412 | ADDED 3
# STEP 2064 | SCORE 5000.0 | DEPTH 96 | ROOTS 1679 | AGE 474 | RATIO 3.5422 | ADDED 4
# STEP 1340 | SCORE 2400.0 | DEPTH 77 | ROOTS 1683 | AGE 475 | RATIO 3.5432 | ADDED 4
# STEP 1750 | SCORE 4300.0 | DEPTH 121 | ROOTS 1686 | AGE 476 | RATIO 3.5420 | ADDED 3
# STEP 1901 | SCORE 4400.0 | DEPTH 79 | ROOTS 1689 | AGE 477 | RATIO 3.5409 | ADDED 3
# STEP 2338 | SCORE 6600.0 | DEPTH 89 | ROOTS 1693 | AGE 478 | RATIO 3.5418 | ADDED 4
# STEP 2067 | SCORE 2900.0 | DEPTH 52 | ROOTS 1696 | AGE 479 | RATIO 3.5407 | ADDED 3
# EPOCH 50/50 | BATCH 4/4 | CURRENT BATCH COUNT 357 | LOSS 11.9333295822143552
# STEP 1891 | SCORE 4200.0 | DEPTH 117 | ROOTS 1699 | AGE 480 | RATIO 3.5396 | ADDED 3
# STEP 2591 | SCORE 6700.0 | DEPTH 117 | ROOTS 1702 | AGE 481 | RATIO 3.5385 | ADDED 3
# STEP 2609 | SCORE 8000.0 | DEPTH 108 | ROOTS 1705 | AGE 482 | RATIO 3.5373 | ADDED 3
# STEP 1892 | SCORE 3200.0 | DEPTH 112 | ROOTS 1709 | AGE 483 | RATIO 3.5383 | ADDED 4
# STEP 1740 | SCORE 3200.0 | DEPTH 71 | ROOTS 1712 | AGE 484 | RATIO 3.5372 | ADDED 3
# STEP 2591 | SCORE 7400.0 | DEPTH 113 | ROOTS 1716 | AGE 485 | RATIO 3.5381 | ADDED 4
# STEP 2402 | SCORE 7400.0 | DEPTH 170 | ROOTS 1719 | AGE 486 | RATIO 3.5370 | ADDED 3
# STEP 2057 | SCORE 4900.0 | DEPTH 110 | ROOTS 1722 | AGE 487 | RATIO 3.5359 | ADDED 3
# STEP 2414 | SCORE 6800.0 | DEPTH 139 | ROOTS 1725 | AGE 488 | RATIO 3.5348 | ADDED 3
# STEP 2072 | SCORE 6100.0 | DEPTH 78 | ROOTS 1729 | AGE 489 | RATIO 3.5358 | ADDED 4
# EPOCH 50/50 | BATCH 4/4 | CURRENT BATCH COUNT 501 | LOSS 12.5276613235473638
# STEP 2227 | SCORE 4500.0 | DEPTH 95 | ROOTS 1732 | AGE 490 | RATIO 3.5347 | ADDED 3
# STEP 2293 | SCORE 6300.0 | DEPTH 87 | ROOTS 1736 | AGE 491 | RATIO 3.5356 | ADDED 4
# STEP 2221 | SCORE 5400.0 | DEPTH 113 | ROOTS 1740 | AGE 492 | RATIO 3.5366 | ADDED 4
# STEP 2393 | SCORE 6100.0 | DEPTH 155 | ROOTS 1743 | AGE 493 | RATIO 3.5355 | ADDED 3
# STEP 2029 | SCORE 3900.0 | DEPTH 99 | ROOTS 1747 | AGE 494 | RATIO 3.5364 | ADDED 4
# STEP 2044 | SCORE 5000.0 | DEPTH 87 | ROOTS 1750 | AGE 495 | RATIO 3.5354 | ADDED 3
# STEP 2163 | SCORE 5000.0 | DEPTH 130 | ROOTS 1753 | AGE 496 | RATIO 3.5343 | ADDED 3
# STEP 1763 | SCORE 4200.0 | DEPTH 93 | ROOTS 1756 | AGE 497 | RATIO 3.5332 | ADDED 3
# STEP 2498 | SCORE 6900.0 | DEPTH 77 | ROOTS 1759 | AGE 498 | RATIO 3.5321 | ADDED 3
# STEP 1835 | SCORE 3900.0 | DEPTH 118 | ROOTS 1762 | AGE 499 | RATIO 3.5311 | ADDED 3
# EPOCH 50/50 | BATCH 4/4 | CURRENT BATCH COUNT 632 | LOSS 11.6147317886352548
# STEP 2378 | SCORE 4600.0 | DEPTH 104 | ROOTS 1766 | AGE 500 | RATIO 3.5320 | ADDED 4
# STEP 2269 | SCORE 5200.0 | DEPTH 111 | ROOTS 1770 | AGE 501 | RATIO 3.5329 | ADDED 4
# STEP 2407 | SCORE 5600.0 | DEPTH 94 | ROOTS 1774 | AGE 502 | RATIO 3.5339 | ADDED 4
# STEP 1653 | SCORE 3000.0 | DEPTH 70 | ROOTS 1777 | AGE 503 | RATIO 3.5328 | ADDED 3
# STEP 1437 | SCORE 2200.0 | DEPTH 57 | ROOTS 1780 | AGE 504 | RATIO 3.5317 | ADDED 3
# STEP 2191 | SCORE 4800.0 | DEPTH 121 | ROOTS 1784 | AGE 505 | RATIO 3.5327 | ADDED 4
# STEP 2127 | SCORE 5500.0 | DEPTH 73 | ROOTS 1788 | AGE 506 | RATIO 3.5336 | ADDED 4
# STEP 1829 | SCORE 3100.0 | DEPTH 115 | ROOTS 1791 | AGE 507 | RATIO 3.5325 | ADDED 3
# STEP 1958 | SCORE 6600.0 | DEPTH 103 | ROOTS 1794 | AGE 508 | RATIO 3.5315 | ADDED 3
# STEP 2105 | SCORE 4500.0 | DEPTH 48 | ROOTS 1797 | AGE 509 | RATIO 3.5305 | ADDED 3
# EPOCH 50/50 | BATCH 4/4 | CURRENT BATCH COUNT 747 | LOSS 12.4152565002441482
# STEP 2258 | SCORE 7700.0 | DEPTH 81 | ROOTS 1801 | AGE 510 | RATIO 3.5314 | ADDED 4
# STEP 2382 | SCORE 5300.0 | DEPTH 125 | ROOTS 1805 | AGE 511 | RATIO 3.5323 | ADDED 4
# STEP 2340 | SCORE 6600.0 | DEPTH 70 | ROOTS 1808 | AGE 512 | RATIO 3.5312 | ADDED 3
# ...
# STEP 1505 | SCORE 2100.0 | DEPTH 79 | ROOTS 4314 | AGE 1280 | RATIO 3.3703 | ADDED 3
# STEP 1596 | SCORE 2400.0 | DEPTH 66 | ROOTS 4317 | AGE 1281 | RATIO 3.3700 | ADDED 3
# STEP 1492 | SCORE 1600.0 | DEPTH 68 | ROOTS 4320 | AGE 1282 | RATIO 3.3697 | ADDED 3
# STEP 1240 | SCORE 800.0 | DEPTH 82 | ROOTS 4323 | AGE 1283 | RATIO 3.3694 | ADDED 3
# STEP 2060 | SCORE 4300.0 | DEPTH 103 | ROOTS 4326 | AGE 1284 | RATIO 3.3692 | ADDED 3
# STEP 1640 | SCORE 1900.0 | DEPTH 66 | ROOTS 4329 | AGE 1285 | RATIO 3.3689 | ADDED 3
# STEP 1448 | SCORE 2400.0 | DEPTH 94 | ROOTS 4332 | AGE 1286 | RATIO 3.3686 | ADDED 3
# STEP 1713 | SCORE 2200.0 | DEPTH 96 | ROOTS 4336 | AGE 1287 | RATIO 3.3691 | ADDED 4
# STEP 1388 | SCORE 900.0 | DEPTH 23 | ROOTS 4339 | AGE 1288 | RATIO 3.3688 | ADDED 3
# STEP 1493 | SCORE 1400.0 | DEPTH 79 | ROOTS 4342 | AGE 1289 | RATIO 3.3685 | ADDED 3
# EPOCH 50/50 | BATCH 9/9 | CURRENT BATCH COUNT 754 | LOSS 11.7623405456542972
# STEP 1463 | SCORE 1900.0 | DEPTH 67 | ROOTS 4345 | AGE 1290 | RATIO 3.3682 | ADDED 3
# STEP 1560 | SCORE 1900.0 | DEPTH 62 | ROOTS 4348 | AGE 1291 | RATIO 3.3679 | ADDED 3
# STEP 1718 | SCORE 3000.0 | DEPTH 109 | ROOTS 4351 | AGE 1292 | RATIO 3.3676 | ADDED 3
# STEP 1618 | SCORE 1900.0 | DEPTH 87 | ROOTS 4354 | AGE 1293 | RATIO 3.3674 | ADDED 3
# STEP 1692 | SCORE 2300.0 | DEPTH 86 | ROOTS 4358 | AGE 1294 | RATIO 3.3679 | ADDED 4
# STEP 1410 | SCORE 1900.0 | DEPTH 30 | ROOTS 4361 | AGE 1295 | RATIO 3.3676 | ADDED 3
# STEP 1684 | SCORE 1100.0 | DEPTH 58 | ROOTS 4364 | AGE 1296 | RATIO 3.3673 | ADDED 3
# STEP 1451 | SCORE 1300.0 | DEPTH 78 | ROOTS 4367 | AGE 1297 | RATIO 3.3670 | ADDED 3
# STEP 1826 | SCORE 3500.0 | DEPTH 89 | ROOTS 4370 | AGE 1298 | RATIO 3.3667 | ADDED 3
# STEP 1523 | SCORE 1400.0 | DEPTH 67 | ROOTS 4373 | AGE 1299 | RATIO 3.3664 | ADDED 3
# EPOCH 50/50 | BATCH 9/9 | CURRENT BATCH COUNT 812 | LOSS 11.7161273956298831
# STEP 1535 | SCORE 2200.0 | DEPTH 82 | ROOTS 4376 | AGE 1300 | RATIO 3.3662 | ADDED 3
# STEP 1563 | SCORE 1700.0 | DEPTH 53 | ROOTS 4380 | AGE 1301 | RATIO 3.3666 | ADDED 4
# STEP 1941 | SCORE 2200.0 | DEPTH 113 | ROOTS 4383 | AGE 1302 | RATIO 3.3664 | ADDED 3
# STEP 2095 | SCORE 4900.0 | DEPTH 71 | ROOTS 4387 | AGE 1303 | RATIO 3.3668 | ADDED 4
# STEP 1852 | SCORE 2500.0 | DEPTH 66 | ROOTS 4390 | AGE 1304 | RATIO 3.3666 | ADDED 3
# STEP 1551 | SCORE 2400.0 | DEPTH 62 | ROOTS 4393 | AGE 1305 | RATIO 3.3663 | ADDED 3
# STEP 1439 | SCORE 2000.0 | DEPTH 44 | ROOTS 4396 | AGE 1306 | RATIO 3.3660 | ADDED 3
# STEP 1610 | SCORE 1400.0 | DEPTH 77 | ROOTS 4400 | AGE 1307 | RATIO 3.3665 | ADDED 4
# STEP 1268 | SCORE 1800.0 | DEPTH 33 | ROOTS 4403 | AGE 1308 | RATIO 3.3662 | ADDED 3
# STEP 1254 | SCORE 1200.0 | DEPTH 64 | ROOTS 4406 | AGE 1309 | RATIO 3.3659 | ADDED 3
# EPOCH 50/50 | BATCH 9/9 | CURRENT BATCH COUNT 874 | LOSS 11.9653387069702154
# STEP 1527 | SCORE 2000.0 | DEPTH 72 | ROOTS 4409 | AGE 1310 | RATIO 3.3656 | ADDED 3
# STEP 1299 | SCORE 1100.0 | DEPTH 69 | ROOTS 4412 | AGE 1311 | RATIO 3.3654 | ADDED 3
# STEP 1598 | SCORE 1800.0 | DEPTH 60 | ROOTS 4415 | AGE 1312 | RATIO 3.3651 | ADDED 3
# STEP 1933 | SCORE 3600.0 | DEPTH 65 | ROOTS 4418 | AGE 1313 | RATIO 3.3648 | ADDED 3
# STEP 1624 | SCORE 1300.0 | DEPTH 87 | ROOTS 4421 | AGE 1314 | RATIO 3.3645 | ADDED 3
# STEP 1940 | SCORE 2700.0 | DEPTH 115 | ROOTS 4424 | AGE 1315 | RATIO 3.3643 | ADDED 3
# STEP 1414 | SCORE 1700.0 | DEPTH 91 | ROOTS 4427 | AGE 1316 | RATIO 3.3640 | ADDED 3
# STEP 1592 | SCORE 1900.0 | DEPTH 69 | ROOTS 4431 | AGE 1317 | RATIO 3.3645 | ADDED 4
# STEP 1510 | SCORE 900.0 | DEPTH 73 | ROOTS 4434 | AGE 1318 | RATIO 3.3642 | ADDED 3
# STEP 1574 | SCORE 1400.0 | DEPTH 85 | ROOTS 4437 | AGE 1319 | RATIO 3.3639 | ADDED 3
# EPOCH 50/50 | BATCH 9/9 | CURRENT BATCH COUNT 925 | LOSS 11.4038324356079191
# STEP 1813 | SCORE 2300.0 | DEPTH 78 | ROOTS 4440 | AGE 1320 | RATIO 3.3636 | ADDED 3
# STEP 1688 | SCORE 2200.0 | DEPTH 91 | ROOTS 4444 | AGE 1321 | RATIO 3.3641 | ADDED 4
# STEP 1556 | SCORE 2700.0 | DEPTH 76 | ROOTS 4447 | AGE 1322 | RATIO 3.3638 | ADDED 3
# STEP 2065 | SCORE 3200.0 | DEPTH 88 | ROOTS 4450 | AGE 1323 | RATIO 3.3636 | ADDED 3
# STEP 1287 | SCORE 900.0 | DEPTH 61 | ROOTS 4453 | AGE 1324 | RATIO 3.3633 | ADDED 3
# STEP 1596 | SCORE 1700.0 | DEPTH 56 | ROOTS 4456 | AGE 1325 | RATIO 3.3630 | ADDED 3
# STEP 1671 | SCORE 2200.0 | DEPTH 76 | ROOTS 4459 | AGE 1326 | RATIO 3.3627 | ADDED 3
# STEP 1385 | SCORE 2900.0 | DEPTH 29 | ROOTS 4463 | AGE 1327 | RATIO 3.3632 | ADDED 4
# STEP 1452 | SCORE 1400.0 | DEPTH 52 | ROOTS 4466 | AGE 1328 | RATIO 3.3630 | ADDED 3
# STEP 1593 | SCORE 1700.0 | DEPTH 67 | ROOTS 4469 | AGE 1329 | RATIO 3.3627 | ADDED 3
# EPOCH 50/50 | BATCH 9/9 | CURRENT BATCH COUNT 985 | LOSS 10.9203262329101566
# STEP 1144 | SCORE 900.0 | DEPTH 55 | ROOTS 4472 | AGE 1330 | RATIO 3.3624 | ADDED 3
# STEP 1348 | SCORE 900.0 | DEPTH 54 | ROOTS 4475 | AGE 1331 | RATIO 3.3621 | ADDED 3
# STEP 1401 | SCORE 1200.0 | DEPTH 57 | ROOTS 4478 | AGE 1332 | RATIO 3.3619 | ADDED 3
# STEP 1579 | SCORE 1200.0 | DEPTH 57 | ROOTS 4482 | AGE 1333 | RATIO 3.3623 | ADDED 4
# STEP 1463 | SCORE 700.0 | DEPTH 82 | ROOTS 4486 | AGE 1334 | RATIO 3.3628 | ADDED 4
# STEP 1828 | SCORE 2200.0 | DEPTH 122 | ROOTS 4489 | AGE 1335 | RATIO 3.3625 | ADDED 3
# STEP 1294 | SCORE 1600.0 | DEPTH 38 | ROOTS 4493 | AGE 1336 | RATIO 3.3630 | ADDED 4
# STEP 1383 | SCORE 800.0 | DEPTH 55 | ROOTS 4496 | AGE 1337 | RATIO 3.3628 | ADDED 3
# STEP 1472 | SCORE 2000.0 | DEPTH 102 | ROOTS 4499 | AGE 1338 | RATIO 3.3625 | ADDED 3
# STEP 1236 | SCORE 800.0 | DEPTH 55 | ROOTS 4502 | AGE 1339 | RATIO 3.3622 | ADDED 3
# EPOCH 50/50 | BATCH 9/9 | CURRENT BATCH COUNT 1022 | LOSS 12.192176818847656
# STEP 1260 | SCORE 3000.0 | DEPTH 40 | ROOTS 4505 | AGE 1340 | RATIO 3.3619 | ADDED 3
# STEP 1920 | SCORE 2400.0 | DEPTH 66 | ROOTS 4508 | AGE 1341 | RATIO 3.3617 | ADDED 3
# STEP 1313 | SCORE 1000.0 | DEPTH 94 | ROOTS 4511 | AGE 1342 | RATIO 3.3614 | ADDED 3
# STEP 1547 | SCORE 1700.0 | DEPTH 100 | ROOTS 4514 | AGE 1343 | RATIO 3.3611 | ADDED 3
# STEP 1964 | SCORE 2100.0 | DEPTH 89 | ROOTS 4518 | AGE 1344 | RATIO 3.3616 | ADDED 4
# STEP 1456 | SCORE 2600.0 | DEPTH 55 | ROOTS 4522 | AGE 1345 | RATIO 3.3621 | ADDED 4
# STEP 1614 | SCORE 1500.0 | DEPTH 71 | ROOTS 4525 | AGE 1346 | RATIO 3.3618 | ADDED 3
# STEP 1499 | SCORE 1600.0 | DEPTH 50 | ROOTS 4528 | AGE 1347 | RATIO 3.3615 | ADDED 3
# STEP 1847 | SCORE 3200.0 | DEPTH 85 | ROOTS 4531 | AGE 1348 | RATIO 3.3613 | ADDED 3
# STEP 1820 | SCORE 2300.0 | DEPTH 91 | ROOTS 4534 | AGE 1349 | RATIO 3.3610 | ADDED 3
# EPOCH 50/50 | BATCH 10/10 | CURRENT BATCH COUNT 57 | LOSS 11.1958770751953124
# STEP 1629 | SCORE 1600.0 | DEPTH 57 | ROOTS 4538 | AGE 1350 | RATIO 3.3615 | ADDED 4
# STEP 1179 | SCORE 800.0 | DEPTH 81 | ROOTS 4542 | AGE 1351 | RATIO 3.3620 | ADDED 4
# STEP 1585 | SCORE 2200.0 | DEPTH 75 | ROOTS 4545 | AGE 1352 | RATIO 3.3617 | ADDED 3
# STEP 1818 | SCORE 3100.0 | DEPTH 53 | ROOTS 4548 | AGE 1353 | RATIO 3.3614 | ADDED 3
# STEP 1564 | SCORE 2200.0 | DEPTH 58 | ROOTS 4552 | AGE 1354 | RATIO 3.3619 | ADDED 4
# STEP 2026 | SCORE 1900.0 | DEPTH 105 | ROOTS 4555 | AGE 1355 | RATIO 3.3616 | ADDED 3
# STEP 1853 | SCORE 1900.0 | DEPTH 64 | ROOTS 4558 | AGE 1356 | RATIO 3.3614 | ADDED 3
# STEP 1596 | SCORE 1100.0 | DEPTH 79 | ROOTS 4561 | AGE 1357 | RATIO 3.3611 | ADDED 3
# STEP 1417 | SCORE 1300.0 | DEPTH 75 | ROOTS 4564 | AGE 1358 | RATIO 3.3608 | ADDED 3
# STEP 1409 | SCORE 1900.0 | DEPTH 95 | ROOTS 4567 | AGE 1359 | RATIO 3.3606 | ADDED 3
# EPOCH 50/50 | BATCH 10/10 | CURRENT BATCH COUNT 105 | LOSS 11.484353065490723
# STEP 1575 | SCORE 2500.0 | DEPTH 120 | ROOTS 4570 | AGE 1360 | RATIO 3.3603 | ADDED 3
# STEP 1389 | SCORE 700.0 | DEPTH 75 | ROOTS 4573 | AGE 1361 | RATIO 3.3600 | ADDED 3
# STEP 1587 | SCORE 1100.0 | DEPTH 68 | ROOTS 4577 | AGE 1362 | RATIO 3.3605 | ADDED 4
# STEP 1463 | SCORE 1400.0 | DEPTH 31 | ROOTS 4580 | AGE 1363 | RATIO 3.3602 | ADDED 3
# STEP 1680 | SCORE 1500.0 | DEPTH 106 | ROOTS 4583 | AGE 1364 | RATIO 3.3600 | ADDED 3
# STEP 1681 | SCORE 2600.0 | DEPTH 57 | ROOTS 4586 | AGE 1365 | RATIO 3.3597 | ADDED 3
# STEP 1642 | SCORE 1600.0 | DEPTH 36 | ROOTS 4589 | AGE 1366 | RATIO 3.3594 | ADDED 3
# STEP 1706 | SCORE 1800.0 | DEPTH 58 | ROOTS 4592 | AGE 1367 | RATIO 3.3592 | ADDED 3
# STEP 1628 | SCORE 1500.0 | DEPTH 67 | ROOTS 4595 | AGE 1368 | RATIO 3.3589 | ADDED 3
# STEP 1387 | SCORE 1700.0 | DEPTH 73 | ROOTS 4598 | AGE 1369 | RATIO 3.3587 | ADDED 3
# EPOCH 50/50 | BATCH 10/10 | CURRENT BATCH COUNT 146 | LOSS 12.011748313903809
# STEP 1434 | SCORE 600.0 | DEPTH 38 | ROOTS 4601 | AGE 1370 | RATIO 3.3584 | ADDED 3
# STEP 1684 | SCORE 1900.0 | DEPTH 116 | ROOTS 4604 | AGE 1371 | RATIO 3.3581 | ADDED 3
# STEP 1962 | SCORE 3000.0 | DEPTH 113 | ROOTS 4607 | AGE 1372 | RATIO 3.3579 | ADDED 3
# STEP 1682 | SCORE 3200.0 | DEPTH 109 | ROOTS 4610 | AGE 1373 | RATIO 3.3576 | ADDED 3
# STEP 1921 | SCORE 1700.0 | DEPTH 33 | ROOTS 4613 | AGE 1374 | RATIO 3.3574 | ADDED 3
# STEP 1624 | SCORE 1600.0 | DEPTH 70 | ROOTS 4616 | AGE 1375 | RATIO 3.3571 | ADDED 3
# STEP 1607 | SCORE 2400.0 | DEPTH 67 | ROOTS 4619 | AGE 1376 | RATIO 3.3568 | ADDED 3
# STEP 1696 | SCORE 2100.0 | DEPTH 79 | ROOTS 4622 | AGE 1377 | RATIO 3.3566 | ADDED 3
# STEP 1680 | SCORE 3100.0 | DEPTH 85 | ROOTS 4625 | AGE 1378 | RATIO 3.3563 | ADDED 3
# STEP 1722 | SCORE 3200.0 | DEPTH 58 | ROOTS 4628 | AGE 1379 | RATIO 3.3561 | ADDED 3
# EPOCH 50/50 | BATCH 10/10 | CURRENT BATCH COUNT 208 | LOSS 11.178339958190918
# STEP 1778 | SCORE 3100.0 | DEPTH 63 | ROOTS 4632 | AGE 1380 | RATIO 3.3565 | ADDED 4
# STEP 1302 | SCORE 700.0 | DEPTH 66 | ROOTS 4635 | AGE 1381 | RATIO 3.3563 | ADDED 3
# STEP 1575 | SCORE 1000.0 | DEPTH 87 | ROOTS 4638 | AGE 1382 | RATIO 3.3560 | ADDED 3
# STEP 1383 | SCORE 1100.0 | DEPTH 73 | ROOTS 4642 | AGE 1383 | RATIO 3.3565 | ADDED 4
# STEP 1505 | SCORE 2300.0 | DEPTH 91 | ROOTS 4645 | AGE 1384 | RATIO 3.3562 | ADDED 3
# STEP 1559 | SCORE 2900.0 | DEPTH 94 | ROOTS 4648 | AGE 1385 | RATIO 3.3560 | ADDED 3
# STEP 1499 | SCORE 1300.0 | DEPTH 65 | ROOTS 4651 | AGE 1386 | RATIO 3.3557 | ADDED 3
# STEP 1508 | SCORE 2300.0 | DEPTH 44 | ROOTS 4654 | AGE 1387 | RATIO 3.3554 | ADDED 3
# STEP 1350 | SCORE 700.0 | DEPTH 48 | ROOTS 4657 | AGE 1388 | RATIO 3.3552 | ADDED 3
# STEP 1294 | SCORE 400.0 | DEPTH 55 | ROOTS 4661 | AGE 1389 | RATIO 3.3557 | ADDED 4
# EPOCH 50/50 | BATCH 10/10 | CURRENT BATCH COUNT 249 | LOSS 11.271876335144043
# STEP 1976 | SCORE 3300.0 | DEPTH 78 | ROOTS 4664 | AGE 1390 | RATIO 3.3554 | ADDED 3
# STEP 1241 | SCORE 1200.0 | DEPTH 65 | ROOTS 4667 | AGE 1391 | RATIO 3.3551 | ADDED 3
# STEP 1380 | SCORE 1600.0 | DEPTH 79 | ROOTS 4670 | AGE 1392 | RATIO 3.3549 | ADDED 3
# STEP 1515 | SCORE 3100.0 | DEPTH 68 | ROOTS 4673 | AGE 1393 | RATIO 3.3546 | ADDED 3
# STEP 1789 | SCORE 3000.0 | DEPTH 85 | ROOTS 4676 | AGE 1394 | RATIO 3.3544 | ADDED 3
# STEP 1466 | SCORE 1400.0 | DEPTH 73 | ROOTS 4679 | AGE 1395 | RATIO 3.3541 | ADDED 3
# STEP 1740 | SCORE 1600.0 | DEPTH 51 | ROOTS 4683 | AGE 1396 | RATIO 3.3546 | ADDED 4
# STEP 1409 | SCORE 1000.0 | DEPTH 70 | ROOTS 4686 | AGE 1397 | RATIO 3.3543 | ADDED 3
# STEP 1472 | SCORE 1500.0 | DEPTH 55 | ROOTS 4689 | AGE 1398 | RATIO 3.3541 | ADDED 3
# STEP 1307 | SCORE 1400.0 | DEPTH 57 | ROOTS 4692 | AGE 1399 | RATIO 3.3538 | ADDED 3
# EPOCH 50/50 | BATCH 10/10 | CURRENT BATCH COUNT 303 | LOSS 11.604986190795898
# STEP 1253 | SCORE 1100.0 | DEPTH 49 | ROOTS 4695 | AGE 1400 | RATIO 3.3536 | ADDED 3
# STEP 1708 | SCORE 2100.0 | DEPTH 45 | ROOTS 4698 | AGE 1401 | RATIO 3.3533 | ADDED 3
# STEP 1592 | SCORE 1100.0 | DEPTH 76 | ROOTS 4701 | AGE 1402 | RATIO 3.3531 | ADDED 3
# STEP 1139 | SCORE 900.0 | DEPTH 37 | ROOTS 4704 | AGE 1403 | RATIO 3.3528 | ADDED 3
# STEP 1290 | SCORE 300.0 | DEPTH 54 | ROOTS 4708 | AGE 1404 | RATIO 3.3533 | ADDED 4
# STEP 1493 | SCORE 1000.0 | DEPTH 76 | ROOTS 4711 | AGE 1405 | RATIO 3.3530 | ADDED 3
# STEP 1622 | SCORE 2000.0 | DEPTH 80 | ROOTS 4715 | AGE 1406 | RATIO 3.3535 | ADDED 4
# STEP 1461 | SCORE 1000.0 | DEPTH 49 | ROOTS 4719 | AGE 1407 | RATIO 3.3539 | ADDED 4
# STEP 1553 | SCORE 2500.0 | DEPTH 102 | ROOTS 4722 | AGE 1408 | RATIO 3.3537 | ADDED 3
# STEP 1325 | SCORE 700.0 | DEPTH 43 | ROOTS 4725 | AGE 1409 | RATIO 3.3534 | ADDED 3
# EPOCH 50/50 | BATCH 10/10 | CURRENT BATCH COUNT 341 | LOSS 11.738267898559573
# STEP 1701 | SCORE 2300.0 | DEPTH 108 | ROOTS 4728 | AGE 1410 | RATIO 3.3532 | ADDED 3
# STEP 1324 | SCORE 1000.0 | DEPTH 46 | ROOTS 4731 | AGE 1411 | RATIO 3.3529 | ADDED 3
# STEP 1320 | SCORE 1400.0 | DEPTH 49 | ROOTS 4734 | AGE 1412 | RATIO 3.3527 | ADDED 3
# STEP 1339 | SCORE 400.0 | DEPTH 77 | ROOTS 4738 | AGE 1413 | RATIO 3.3531 | ADDED 4
# STEP 1698 | SCORE 1900.0 | DEPTH 63 | ROOTS 4741 | AGE 1414 | RATIO 3.3529 | ADDED 3
# STEP 1608 | SCORE 2300.0 | DEPTH 88 | ROOTS 4744 | AGE 1415 | RATIO 3.3527 | ADDED 3
# STEP 1321 | SCORE 2300.0 | DEPTH 44 | ROOTS 4747 | AGE 1416 | RATIO 3.3524 | ADDED 3
# STEP 1821 | SCORE 1500.0 | DEPTH 95 | ROOTS 4750 | AGE 1417 | RATIO 3.3522 | ADDED 3
# STEP 1253 | SCORE 300.0 | DEPTH 62 | ROOTS 4753 | AGE 1418 | RATIO 3.3519 | ADDED 3
# STEP 1455 | SCORE 1100.0 | DEPTH 80 | ROOTS 4756 | AGE 1419 | RATIO 3.3517 | ADDED 3
# EPOCH 50/50 | BATCH 10/10 | CURRENT BATCH COUNT 384 | LOSS 11.204412460327148
# STEP 1630 | SCORE 1400.0 | DEPTH 72 | ROOTS 4759 | AGE 1420 | RATIO 3.3514 | ADDED 3
# STEP 1381 | SCORE 1600.0 | DEPTH 85 | ROOTS 4762 | AGE 1421 | RATIO 3.3512 | ADDED 3
# STEP 2045 | SCORE 3600.0 | DEPTH 118 | ROOTS 4765 | AGE 1422 | RATIO 3.3509 | ADDED 3
# STEP 1435 | SCORE 1000.0 | DEPTH 91 | ROOTS 4768 | AGE 1423 | RATIO 3.3507 | ADDED 3
# STEP 1632 | SCORE 3000.0 | DEPTH 87 | ROOTS 4771 | AGE 1424 | RATIO 3.3504 | ADDED 3
# STEP 1424 | SCORE 800.0 | DEPTH 51 | ROOTS 4774 | AGE 1425 | RATIO 3.3502 | ADDED 3
# STEP 1616 | SCORE 2300.0 | DEPTH 104 | ROOTS 4777 | AGE 1426 | RATIO 3.3499 | ADDED 3
# STEP 1293 | SCORE 1100.0 | DEPTH 63 | ROOTS 4780 | AGE 1427 | RATIO 3.3497 | ADDED 3
# STEP 1717 | SCORE 2800.0 | DEPTH 66 | ROOTS 4783 | AGE 1428 | RATIO 3.3494 | ADDED 3
# STEP 1378 | SCORE 900.0 | DEPTH 56 | ROOTS 4786 | AGE 1429 | RATIO 3.3492 | ADDED 3
# EPOCH 50/50 | BATCH 10/10 | CURRENT BATCH COUNT 436 | LOSS 11.522432327270508
# STEP 1544 | SCORE 1600.0 | DEPTH 50 | ROOTS 4789 | AGE 1430 | RATIO 3.3490 | ADDED 3
# STEP 1645 | SCORE 2400.0 | DEPTH 72 | ROOTS 4793 | AGE 1431 | RATIO 3.3494 | ADDED 4
# STEP 1553 | SCORE 1700.0 | DEPTH 69 | ROOTS 4797 | AGE 1432 | RATIO 3.3499 | ADDED 4
# STEP 864 | SCORE 200.0 | DEPTH 29 | ROOTS 4801 | AGE 1433 | RATIO 3.3503 | ADDED 4
# STEP 1677 | SCORE 1200.0 | DEPTH 56 | ROOTS 4804 | AGE 1434 | RATIO 3.3501 | ADDED 3
# STEP 1462 | SCORE 1400.0 | DEPTH 74 | ROOTS 4808 | AGE 1435 | RATIO 3.3505 | ADDED 4
# STEP 1623 | SCORE 2500.0 | DEPTH 112 | ROOTS 4811 | AGE 1436 | RATIO 3.3503 | ADDED 3
# STEP 1656 | SCORE 2000.0 | DEPTH 71 | ROOTS 4814 | AGE 1437 | RATIO 3.3500 | ADDED 3
# STEP 1487 | SCORE 1700.0 | DEPTH 47 | ROOTS 4817 | AGE 1438 | RATIO 3.3498 | ADDED 3
# STEP 1545 | SCORE 1700.0 | DEPTH 80 | ROOTS 4820 | AGE 1439 | RATIO 3.3495 | ADDED 3
# EPOCH 50/50 | BATCH 10/10 | CURRENT BATCH COUNT 480 | LOSS 11.868019104003906
# STEP 1272 | SCORE 800.0 | DEPTH 32 | ROOTS 4824 | AGE 1440 | RATIO 3.3500 | ADDED 4
# STEP 2244 | SCORE 2900.0 | DEPTH 80 | ROOTS 4827 | AGE 1441 | RATIO 3.3498 | ADDED 3
# STEP 1828 | SCORE 2200.0 | DEPTH 48 | ROOTS 4831 | AGE 1442 | RATIO 3.3502 | ADDED 4
# STEP 1810 | SCORE 2700.0 | DEPTH 90 | ROOTS 4835 | AGE 1443 | RATIO 3.3507 | ADDED 4
# STEP 1978 | SCORE 4200.0 | DEPTH 66 | ROOTS 4838 | AGE 1444 | RATIO 3.3504 | ADDED 3
# STEP 1447 | SCORE 700.0 | DEPTH 59 | ROOTS 4841 | AGE 1445 | RATIO 3.3502 | ADDED 3
# STEP 1764 | SCORE 1500.0 | DEPTH 130 | ROOTS 4844 | AGE 1446 | RATIO 3.3499 | ADDED 3
# STEP 1736 | SCORE 1800.0 | DEPTH 99 | ROOTS 4847 | AGE 1447 | RATIO 3.3497 | ADDED 3
# STEP 542 | SCORE 1100.0 | DEPTH 50 | ROOTS 4848 | AGE 1448 | RATIO 3.3481 | ADDED 1
